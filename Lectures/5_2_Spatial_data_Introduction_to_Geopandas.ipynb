# %% [markdown]
# <a href="https://colab.research.google.com/github/armitakar/GGS366_Spatial_Computing/blob/main/Lectures/5_2_Spatial_data_Introduction_to_Geopandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *GeoPandas is a project to add support for geographic data to pandas objects. It currently implements GeoSeries and GeoDataFrame types which are subclasses of pandas.Series and pandas.DataFrame respectively.*
#
# See the Git repo for more information: https://github.com/geopandas/geopandas
#
# The key difference between Pandas and GeoPandas is that GeoPandas includes a geometry column in its DataFrame, which allows it to store spatial data as one or multiple coordinate pairs (e.g., latitude and longitude), enabling spatial operations and geographic analysis.

# %% [markdown]
# We will get started with importing the Pandas and GeoPandas library.

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# In this lecture, we will be heavily using administrative boundaries such as state, county, census tract, and block groups, often organized by their **FIPS codes**.
#
# Here's a basic structure of FIPS codes used for different administrative boundaries:
#
#
# ![image](https://drive.google.com/uc?export=view&id=1RBFiGGqTQtzRxbi6gfeeEMc4gxFEB9tU)
#
# Concatenating various levels of FIPS codes, we get the GEOID.

# %% [markdown]
# # Importing shapefile

# %% [markdown]
# We can read geospatial data using the **.read_file()** function, which supports various file formats, including shapefiles, GeoJSON, and GeoPackage.
#
# For this example, we will use a shapefile, but you can explore how to import other geospatial formats as well. While it's possible to load data from your local machine using the files module, as we did in the previous lecture, here we will directly read a **Virginia census tracts shapefile** from the [TIGER/Line Shapefiles page](https://www.census.gov/geographies/mapping-files/time-series/geo/tiger-line-file.html).
#
# In this way, we can work with publicly available geospatial data without needing to download files manually.

# %%
# Access shapefile of Virginia census tracts
# the FIPS code for virginia is 51, you may change this for other states
va_tract = gpd.read_file("https://www2.census.gov/geo/tiger/TIGER2022/TRACT/tl_2022_51_tract.zip")

# %% [markdown]
# We can use the basic single color plot to take a quick look at the data we just downloaded. We will learn more about mapping in the upcoming classes.

# %%
# Basic single color plot
va_tract.plot()
# Out:
# <Axes: >

# %% [markdown]
# As mentioned earlier, the main difference between Pandas and GeoPandas lies in the presence of a geometry column in GeoPandas. Otherwise, all standard Pandas functions are fully compatible with GeoPandas. For example, we can use common data exploration functions such as head() to preview the first few rows and shape to check the number of rows and columns in a GeoDataFrame, just as we would in a regular Pandas DataFrame.

# %%
va_tract.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  MTFCC  \
# 0      51      013  101502  51013101502  1015.02  Census Tract 1015.02  G5020
# 1      51      013  101804  51013101804  1018.04  Census Tract 1018.04  G5020
# 2      51      013  101705  51013101705  1017.05  Census Tract 1017.05  G5020
# 3      51      013  101704  51013101704  1017.04  Census Tract 1017.04  G5020
# 4      51      013  103505  51013103505  1035.05  Census Tract 1035.05  G5020
#
#   FUNCSTAT   ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0        S  635955       0  +38.8907435  -077.0928398
# 1        S  195431       0  +38.8866986  -077.0879512
# 2        S  282555       0  +38.8927606  -077.0755724
# 3        S   99908       0  +38.8928523  -077.0696004
# 4        S  538888       0  +38.8613937  -077.0598298
#
#                                             geometry
# 0  POLYGON ((-77.10057 38.88762, -77.10039 38.887...
# 1  POLYGON ((-77.09069 38.88963, -77.09048 38.889...
# 2  POLYGON ((-77.08027 38.89324, -77.07986 38.893...
# 3  POLYGON ((-77.07151 38.89249, -77.07147 38.892...
# 4  POLYGON ((-77.06371 38.86277, -77.0637 38.8629...

# %%
va_tract.shape
# Out:
# (2198, 13)

# %% [markdown]
# # Coordinate Reference Systems (CRS)

# %% [markdown]
# GeoPandas can automatically store the Coordinate Reference System (CRS) as an attribute when loading spatial objects. These objects can then be transformed to a different CRS using the .to_crs() method.
#
# There are two main types of Coordinate Reference Systems (CRS):
#
# - **Geographic Coordinate System (GCS):**
#   - A GCS measures locations on Earth using latitude and longitude, based on a spherical or ellipsoidal model of the Earth.
#   - Latitude is measured in degrees north or south of the equator.
#   - Longitude is measured in degrees east or west of the prime meridian.
#   - Example: The World Geodetic System (WGS84) (EPSG:4326) is one of the most widely used geographic coordinate systems.
#
# - **Projected Coordinate System (PCS):**
#   - A PCS transforms the 3D surface of the Earth onto a 2D flat plane and measures locations using Cartesian coordinates (x, y).
#   - The location coordinates are typically measured in meters or feet.
#   - Examples: The Universal Transverse Mercator (UTM) and WGS 84 Pseudo-Mercator (EPSG:3857) are common projected coordinate systems.
#
# There are hundreds of different CRS types, each suited to different geographic regions to maintain consistency and accuracy in measurements. For instance, while WGS84 (EPSG:4326) and North American Datum of 1983 (NAD83) (EPSG:4269) are both geographic coordinate systems, NAD83 is more appropriate for the United States. This is because NAD83 is specifically designed to minimize errors in mapping and positioning within North America, taking into account the local shape and size of the Earth in this region, while WGS84 is globally used but has slight inaccuracies in some local areas.
#
# We can easily check the current CRS of our data using the .crs function, as follows.

# %%
# current crs of the data
va_tract.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -40.73, 86.45)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# With GeoPandas, we can change the Coordinate Reference System (CRS) using the **.to_crs()** function. For example, our the data is currently in a geographic coordinate system like **North American Datum 1983 (NAD83) (EPSG: 4269)**, which is measured in **decimal degrees**, we can transform it into **a projected coordinate system such as EPSG: 3857**, which is measured in **meters**. See how the geometry values have changed after this conversion.

# %%
va_tract.to_crs(epsg = 3857)
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  \
# 0         51      013  101502  51013101502  1015.02  Census Tract 1015.02
# 1         51      013  101804  51013101804  1018.04  Census Tract 1018.04
# 2         51      013  101705  51013101705  1017.05  Census Tract 1017.05
# 3         51      013  101704  51013101704  1017.04  Census Tract 1017.04
# 4         51      013  103505  51013103505  1035.05  Census Tract 1035.05
# ...      ...      ...     ...          ...      ...                   ...
# 2193      51      165  010600  51165010600      106      Census Tract 106
# 2194      51      165  011700  51165011700      117      Census Tract 117
# 2195      51      165  010700  51165010700      107      Census Tract 107
# 2196      51      165  010400  51165010400      104      Census Tract 104
# 2197      51      165  011500  51165011500      115      Census Tract 115
#
#       MTFCC FUNCSTAT      ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0     G5020        S     635955       0  +38.8907435  -077.0928398
# 1     G5020        S     195431       0  +38.8866986  -077.0879512
# 2     G5020        S     282555       0  +38.8927606  -077.0755724
# 3     G5020        S      99908       0  +38.8928523  -077.0696004
# 4     G5020        S     538888       0  +38.8613937  -077.0598298
# ...     ...      ...        ...     ...          ...           ...
# 2193  G5020        S   91078253  234708  +38.5164322  -078.8525662
# 2194  G5020        S   45806005  468336  +38.3676178  -078.8964855
# 2195  G5020        S   81990253  257288  +38.5880235  -078.8719806
# 2196  G5020        S  110603698  434809  +38.5503609  -078.7168103
# 2197  G5020        S   10292726  225318  +38.3884912  -078.9644518
#
#                                                geometry
# 0     POLYGON ((-8582796.415 4705587.434, -8582776.0...
# 1     POLYGON ((-8581695.91 4705874.325, -8581673.20...
# 2     POLYGON ((-8580536.741 4706391.065, -8580490.2...
# 3     POLYGON ((-8579561.248 4706283.081, -8579556.3...
# 4     POLYGON ((-8578692.733 4702034.001, -8578691.3...
# ...                                                 ...
# 2193  POLYGON ((-8787712.332 4651636.293, -8787656.5...
# 2194  POLYGON ((-8786872.426 4627804.123, -8786871.0...
# 2195  POLYGON ((-8788700.96 4659250.47, -8788699.513...
# 2196  POLYGON ((-8772458.89 4655037.161, -8772419.81...
# 2197  POLYGON ((-8793162.868 4634052.228, -8793144.6...
#
# [2198 rows x 13 columns]

# %% [markdown]
# We can then easily find the area of a set of geometry polygons, such as the shapes we have here, via the **.area** function.

# %%
# Finding the area of polygons
va_tract['area_km2'] = va_tract['geometry'].area / 1e6
va_tract.head()
# Out:
# <ipython-input-8-923f735b9c17>:2: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   va_tract['area_km2'] = va_tract['geometry'].area / 1e6
#   STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  MTFCC  \
# 0      51      013  101502  51013101502  1015.02  Census Tract 1015.02  G5020
# 1      51      013  101804  51013101804  1018.04  Census Tract 1018.04  G5020
# 2      51      013  101705  51013101705  1017.05  Census Tract 1017.05  G5020
# 3      51      013  101704  51013101704  1017.04  Census Tract 1017.04  G5020
# 4      51      013  103505  51013103505  1035.05  Census Tract 1035.05  G5020
#
#   FUNCSTAT   ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0        S  635955       0  +38.8907435  -077.0928398
# 1        S  195431       0  +38.8866986  -077.0879512
# 2        S  282555       0  +38.8927606  -077.0755724
# 3        S   99908       0  +38.8928523  -077.0696004
# 4        S  538888       0  +38.8613937  -077.0598298
#
#                                             geometry      area_km2
# 0  POLYGON ((-77.10057 38.88762, -77.10039 38.887...  6.602912e-11
# 1  POLYGON ((-77.09069 38.88963, -77.09048 38.889...  2.028987e-11
# 2  POLYGON ((-77.08027 38.89324, -77.07986 38.893...  2.933758e-11
# 3  POLYGON ((-77.07151 38.89249, -77.07147 38.892...  1.037361e-11
# 4  POLYGON ((-77.06371 38.86277, -77.0637 38.8629...  5.592813e-11

# %% [markdown]
# # Census data

# %% [markdown]
# We can extract census data to obtain additional socio-economic information about these census tracts. Census data is available in various forms, such as the Decennial Survey, American Community Survey (ACS) 5-Year Estimates, ACS 1-Year Estimates, and more. For this exercise, we will focus on the ACS 5-Year Estimates dataset.
#
# Using FIPS codes, you can identify specific regions within the dataset and filter the data accordingly.

# %% [markdown]
# First we need to **install and load the census library**.

# %%
# Installing the library
# !pip install census
# Out:
# Requirement already satisfied: census in /usr/local/lib/python3.11/dist-packages (0.8.23)
# Requirement already satisfied: requests>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from census) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=1.1.0->census) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=1.1.0->census) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=1.1.0->census) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=1.1.0->census) (2025.1.31)

# %%
# loading census library
from census import Census

# %% [markdown]
# The census library needs an API key to function. You can request the API keys from here: https://api.census.gov/data/key_signup.html

# %%
# Set API key
c = Census("Insert_your_API_key_here")

# %% [markdown]
# Next, you can use the following functions to extract census tract-specific information for a particular state and county. Census data contains information on many variables, and these variables are represented by coded names. You can find a list of these variable codes and their detailed descriptions at this link: https://api.census.gov/data/2022/acs/acs5/variables.html
#
# In addition, there are other functions available to extract state-level, county-level, blockgroup-level data. You can explore these functions further in the Census Python package documentation: https://pypi.org/project/census/

# %%
#B01001_001E: total population, B01001_002E: total male population, and B01001_026E: total female population
# 51 is FIPS code for Virginia
# * sign to extract all data for all County and tracts
# ACS 5-Year Survey for the year 2022
va_census = c.acs5.state_county_tract(fields = ('NAME', "B01001_001E", "B01001_002E", "B01001_026E"),
                                      state_fips = "51",
                                      county_fips = "*",
                                      tract = "*", year = 2022)

# %% [markdown]
# The data is extracted in a **list of dictionaries** format.

# %%
va_census
# Out:
# [{'NAME': 'Census Tract 901.01; Accomack County; Virginia',
#   'B01001_001E': 1902.0,
#   'B01001_002E': 996.0,
#   'B01001_026E': 906.0,
#   'state': '51',
#   'county': '001',
#   'tract': '090101'},
#  {'NAME': 'Census Tract 901.02; Accomack County; Virginia',
#   'B01001_001E': 1401.0,
#   'B01001_002E': 773.0,
#   'B01001_026E': 628.0,
#   'state': '51',
#   'county': '001',
#   'tract': '090102'},
#  {'NAME': 'Census Tract 902.01; Accomack County; Virginia',
#   'B01001_001E': 3126.0,
#   'B01001_002E': 1507.0,
#   'B01001_026E': 1619.0,
#   'state': '51',
#   'county': '001',
#   'tract': '090201'},
#  {'NAME': 'Census Tract 902.02; Accomack County; Virginia',
#   'B01001_001E': 2772.0,
#   'B01001_002E': 1193.0,
#   'B01001_026E': 1579.0,
#   'state': '51',
#   'county': '001',
#   'tract': '090202'},
#  {'NAME': 'Census Tract 903; Accomack County; Virginia',
#   'B01001_001E': 2225.0,
#   'B01001_002E': 1159.0,
#   'B01001_026E': 1066.0,
#   'state': '51',
#   'county': '001',
#   'tract': '090300'},
#  {'NAME': 'Census Tract 904.01; Accomack County; Virginia',
#   'B01001_001E': 3247.0,
#   'B01001_002E': 1769.0,
#   'B01001_026E': 1478.0,
#   'state': '51',
#   'county': '001',
#   'tract': '090401'},
#  {'NAME': 'Census Tract 904.02; Accomack County; Virginia',
#   'B01001_001E': 3913.0,
#   'B01001_002E': 1857.0,
#   'B01001_026E': 2056.0,
#   'state': '51',
#   'county': '001',
#   'tract': '090402'},
#  {'NAME': 'Census Tract 905; Accomack County; Virginia',
#   'B01001_001E': 2136.0,
#   'B01001_002E': 904.0,
#   'B01001_026E': 1232.0,
#   'state': '51',
#   'county': '001',
#   'tract': '090500'},
#  {'NAME': 'Census Tract 906; Accomack County; Virginia',
#   'B01001_001E': 3821.0,
#   'B01001_002E': 1743.0,
#   'B01001_026E': 2078.0,
#   'state': '51',
#   'county': '001',
#   'tract': '090600'},
#  {'NAME': 'Census Tract 907; Accomack County; Virginia',
#   'B01001_001E': 5148.0,
#   'B01001_002E': 2528.0,
#   'B01001_026E': 2620.0,
#   'state': '51',
#   'county': '001',
#   'tract': '090700'},
#  {'NAME': 'Census Tract 908; Accomack County; Virginia',
#   'B01001_001E': 3652.0,
#   'B01001_002E': 1804.0,
#   'B01001_026E': 1848.0,
#   'state': '51',
#   'county': '001',
#   'tract': '090800'},
#  {'NAME': 'Census Tract 9801; Accomack County; Virginia',
#   'B01001_001E': 24.0,
#   'B01001_002E': 24.0,
#   'B01001_026E': 0.0,
#   'state': '51',
#   'county': '001',
#   'tract': '980100'},
#  {'NAME': 'Census Tract 9802; Accomack County; Virginia',
#   'B01001_001E': 0.0,
#   'B01001_002E': 0.0,
#   'B01001_026E': 0.0,
#   'state': '51',
#   'county': '001',
#   'tract': '980200'},
#  {'NAME': 'Census Tract 9901; Accomack County; Virginia',
#   'B01001_001E': 0.0,
#   'B01001_002E': 0.0,
#   'B01001_026E': 0.0,
#   'state': '51',
#   'county': '001',
#   'tract': '990100'},
#  {'NAME': 'Census Tract 9902; Accomack County; Virginia',
#   'B01001_001E': 0.0,
#   'B01001_002E': 0.0,
#   'B01001_026E': 0.0,
#   'state': '51',
#   'county': '001',
#   'tract': '990200'},
#  {'NAME': 'Census Tract 101; Albemarle County; Virginia',
#   'B01001_001E': 4647.0,
#   'B01001_002E': 2321.0,
#   'B01001_026E': 2326.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010100'},
#  {'NAME': 'Census Tract 102.01; Albemarle County; Virginia',
#   'B01001_001E': 6082.0,
#   'B01001_002E': 2881.0,
#   'B01001_026E': 3201.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010201'},
#  {'NAME': 'Census Tract 102.02; Albemarle County; Virginia',
#   'B01001_001E': 3158.0,
#   'B01001_002E': 1520.0,
#   'B01001_026E': 1638.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010202'},
#  {'NAME': 'Census Tract 103.01; Albemarle County; Virginia',
#   'B01001_001E': 2310.0,
#   'B01001_002E': 1087.0,
#   'B01001_026E': 1223.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010301'},
#  {'NAME': 'Census Tract 103.02; Albemarle County; Virginia',
#   'B01001_001E': 1418.0,
#   'B01001_002E': 734.0,
#   'B01001_026E': 684.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010302'},
#  {'NAME': 'Census Tract 103.03; Albemarle County; Virginia',
#   'B01001_001E': 5385.0,
#   'B01001_002E': 2516.0,
#   'B01001_026E': 2869.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010303'},
#  {'NAME': 'Census Tract 104.01; Albemarle County; Virginia',
#   'B01001_001E': 4447.0,
#   'B01001_002E': 2348.0,
#   'B01001_026E': 2099.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010401'},
#  {'NAME': 'Census Tract 104.02; Albemarle County; Virginia',
#   'B01001_001E': 3470.0,
#   'B01001_002E': 1659.0,
#   'B01001_026E': 1811.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010402'},
#  {'NAME': 'Census Tract 105.01; Albemarle County; Virginia',
#   'B01001_001E': 3014.0,
#   'B01001_002E': 1540.0,
#   'B01001_026E': 1474.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010501'},
#  {'NAME': 'Census Tract 105.02; Albemarle County; Virginia',
#   'B01001_001E': 2741.0,
#   'B01001_002E': 1046.0,
#   'B01001_026E': 1695.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010502'},
#  {'NAME': 'Census Tract 106.02; Albemarle County; Virginia',
#   'B01001_001E': 4711.0,
#   'B01001_002E': 2265.0,
#   'B01001_026E': 2446.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010602'},
#  {'NAME': 'Census Tract 106.03; Albemarle County; Virginia',
#   'B01001_001E': 2480.0,
#   'B01001_002E': 1031.0,
#   'B01001_026E': 1449.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010603'},
#  {'NAME': 'Census Tract 106.04; Albemarle County; Virginia',
#   'B01001_001E': 4090.0,
#   'B01001_002E': 2110.0,
#   'B01001_026E': 1980.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010604'},
#  {'NAME': 'Census Tract 107.01; Albemarle County; Virginia',
#   'B01001_001E': 2825.0,
#   'B01001_002E': 1346.0,
#   'B01001_026E': 1479.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010701'},
#  {'NAME': 'Census Tract 107.02; Albemarle County; Virginia',
#   'B01001_001E': 3017.0,
#   'B01001_002E': 1336.0,
#   'B01001_026E': 1681.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010702'},
#  {'NAME': 'Census Tract 108.01; Albemarle County; Virginia',
#   'B01001_001E': 3470.0,
#   'B01001_002E': 1549.0,
#   'B01001_026E': 1921.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010801'},
#  {'NAME': 'Census Tract 108.02; Albemarle County; Virginia',
#   'B01001_001E': 2518.0,
#   'B01001_002E': 1100.0,
#   'B01001_026E': 1418.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010802'},
#  {'NAME': 'Census Tract 109.01; Albemarle County; Virginia',
#   'B01001_001E': 1941.0,
#   'B01001_002E': 1032.0,
#   'B01001_026E': 909.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010901'},
#  {'NAME': 'Census Tract 109.04; Albemarle County; Virginia',
#   'B01001_001E': 7707.0,
#   'B01001_002E': 4140.0,
#   'B01001_026E': 3567.0,
#   'state': '51',
#   'county': '003',
#   'tract': '010904'},
#  {'NAME': 'Census Tract 110; Albemarle County; Virginia',
#   'B01001_001E': 6671.0,
#   'B01001_002E': 3216.0,
#   'B01001_026E': 3455.0,
#   'state': '51',
#   'county': '003',
#   'tract': '011000'},
#  {'NAME': 'Census Tract 111.01; Albemarle County; Virginia',
#   'B01001_001E': 2399.0,
#   'B01001_002E': 1177.0,
#   'B01001_026E': 1222.0,
#   'state': '51',
#   'county': '003',
#   'tract': '011101'},
#  {'NAME': 'Census Tract 111.02; Albemarle County; Virginia',
#   'B01001_001E': 3145.0,
#   'B01001_002E': 1257.0,
#   'B01001_026E': 1888.0,
#   'state': '51',
#   'county': '003',
#   'tract': '011102'},
#  {'NAME': 'Census Tract 111.03; Albemarle County; Virginia',
#   'B01001_001E': 4159.0,
#   'B01001_002E': 1997.0,
#   'B01001_026E': 2162.0,
#   'state': '51',
#   'county': '003',
#   'tract': '011103'},
#  {'NAME': 'Census Tract 112.01; Albemarle County; Virginia',
#   'B01001_001E': 4142.0,
#   'B01001_002E': 1981.0,
#   'B01001_026E': 2161.0,
#   'state': '51',
#   'county': '003',
#   'tract': '011201'},
#  {'NAME': 'Census Tract 112.02; Albemarle County; Virginia',
#   'B01001_001E': 3859.0,
#   'B01001_002E': 1926.0,
#   'B01001_026E': 1933.0,
#   'state': '51',
#   'county': '003',
#   'tract': '011202'},
#  {'NAME': 'Census Tract 113.01; Albemarle County; Virginia',
#   'B01001_001E': 4929.0,
#   'B01001_002E': 2520.0,
#   'B01001_026E': 2409.0,
#   'state': '51',
#   'county': '003',
#   'tract': '011301'},
#  {'NAME': 'Census Tract 113.02; Albemarle County; Virginia',
#   'B01001_001E': 5106.0,
#   'B01001_002E': 2331.0,
#   'B01001_026E': 2775.0,
#   'state': '51',
#   'county': '003',
#   'tract': '011302'},
#  {'NAME': 'Census Tract 113.03; Albemarle County; Virginia',
#   'B01001_001E': 3975.0,
#   'B01001_002E': 2066.0,
#   'B01001_026E': 1909.0,
#   'state': '51',
#   'county': '003',
#   'tract': '011303'},
#  {'NAME': 'Census Tract 114; Albemarle County; Virginia',
#   'B01001_001E': 4697.0,
#   'B01001_002E': 2036.0,
#   'B01001_026E': 2661.0,
#   'state': '51',
#   'county': '003',
#   'tract': '011400'},
#  {'NAME': 'Census Tract 701; Alleghany County; Virginia',
#   'B01001_001E': 3650.0,
#   'B01001_002E': 1845.0,
#   'B01001_026E': 1805.0,
#   'state': '51',
#   'county': '005',
#   'tract': '070100'},
#  {'NAME': 'Census Tract 801; Alleghany County; Virginia',
#   'B01001_001E': 3440.0,
#   'B01001_002E': 1683.0,
#   'B01001_026E': 1757.0,
#   'state': '51',
#   'county': '005',
#   'tract': '080100'},
#  {'NAME': 'Census Tract 802.01; Alleghany County; Virginia',
#   'B01001_001E': 2708.0,
#   'B01001_002E': 1265.0,
#   'B01001_026E': 1443.0,
#   'state': '51',
#   'county': '005',
#   'tract': '080201'},
#  {'NAME': 'Census Tract 802.02; Alleghany County; Virginia',
#   'B01001_001E': 2212.0,
#   'B01001_002E': 1017.0,
#   'B01001_026E': 1195.0,
#   'state': '51',
#   'county': '005',
#   'tract': '080202'},
#  {'NAME': 'Census Tract 803.01; Alleghany County; Virginia',
#   'B01001_001E': 1721.0,
#   'B01001_002E': 936.0,
#   'B01001_026E': 785.0,
#   'state': '51',
#   'county': '005',
#   'tract': '080301'},
#  {'NAME': 'Census Tract 803.02; Alleghany County; Virginia',
#   'B01001_001E': 1428.0,
#   'B01001_002E': 755.0,
#   'B01001_026E': 673.0,
#   'state': '51',
#   'county': '005',
#   'tract': '080302'},
#  {'NAME': 'Census Tract 9301.01; Amelia County; Virginia',
#   'B01001_001E': 2550.0,
#   'B01001_002E': 1310.0,
#   'B01001_026E': 1240.0,
#   'state': '51',
#   'county': '007',
#   'tract': '930101'},
#  {'NAME': 'Census Tract 9301.02; Amelia County; Virginia',
#   'B01001_001E': 4862.0,
#   'B01001_002E': 2494.0,
#   'B01001_026E': 2368.0,
#   'state': '51',
#   'county': '007',
#   'tract': '930102'},
#  {'NAME': 'Census Tract 9302; Amelia County; Virginia',
#   'B01001_001E': 5897.0,
#   'B01001_002E': 2727.0,
#   'B01001_026E': 3170.0,
#   'state': '51',
#   'county': '007',
#   'tract': '930200'},
#  {'NAME': 'Census Tract 101; Amherst County; Virginia',
#   'B01001_001E': 4885.0,
#   'B01001_002E': 2200.0,
#   'B01001_026E': 2685.0,
#   'state': '51',
#   'county': '009',
#   'tract': '010100'},
#  {'NAME': 'Census Tract 102.01; Amherst County; Virginia',
#   'B01001_001E': 4789.0,
#   'B01001_002E': 2200.0,
#   'B01001_026E': 2589.0,
#   'state': '51',
#   'county': '009',
#   'tract': '010201'},
#  {'NAME': 'Census Tract 102.02; Amherst County; Virginia',
#   'B01001_001E': 2711.0,
#   'B01001_002E': 1321.0,
#   'B01001_026E': 1390.0,
#   'state': '51',
#   'county': '009',
#   'tract': '010202'},
#  {'NAME': 'Census Tract 103; Amherst County; Virginia',
#   'B01001_001E': 3129.0,
#   'B01001_002E': 1576.0,
#   'B01001_026E': 1553.0,
#   'state': '51',
#   'county': '009',
#   'tract': '010300'},
#  {'NAME': 'Census Tract 104.01; Amherst County; Virginia',
#   'B01001_001E': 3747.0,
#   'B01001_002E': 1778.0,
#   'B01001_026E': 1969.0,
#   'state': '51',
#   'county': '009',
#   'tract': '010401'},
#  {'NAME': 'Census Tract 104.02; Amherst County; Virginia',
#   'B01001_001E': 3009.0,
#   'B01001_002E': 1489.0,
#   'B01001_026E': 1520.0,
#   'state': '51',
#   'county': '009',
#   'tract': '010402'},
#  {'NAME': 'Census Tract 105.04; Amherst County; Virginia',
#   'B01001_001E': 3903.0,
#   'B01001_002E': 1873.0,
#   'B01001_026E': 2030.0,
#   'state': '51',
#   'county': '009',
#   'tract': '010504'},
#  {'NAME': 'Census Tract 105.05; Amherst County; Virginia',
#   'B01001_001E': 1047.0,
#   'B01001_002E': 472.0,
#   'B01001_026E': 575.0,
#   'state': '51',
#   'county': '009',
#   'tract': '010505'},
#  {'NAME': 'Census Tract 105.06; Amherst County; Virginia',
#   'B01001_001E': 1732.0,
#   'B01001_002E': 807.0,
#   'B01001_026E': 925.0,
#   'state': '51',
#   'county': '009',
#   'tract': '010506'},
#  {'NAME': 'Census Tract 106; Amherst County; Virginia',
#   'B01001_001E': 2474.0,
#   'B01001_002E': 1257.0,
#   'B01001_026E': 1217.0,
#   'state': '51',
#   'county': '009',
#   'tract': '010600'},
#  {'NAME': 'Census Tract 401.01; Appomattox County; Virginia',
#   'B01001_001E': 4013.0,
#   'B01001_002E': 1804.0,
#   'B01001_026E': 2209.0,
#   'state': '51',
#   'county': '011',
#   'tract': '040101'},
#  {'NAME': 'Census Tract 401.02; Appomattox County; Virginia',
#   'B01001_001E': 3464.0,
#   'B01001_002E': 1769.0,
#   'B01001_026E': 1695.0,
#   'state': '51',
#   'county': '011',
#   'tract': '040102'},
#  {'NAME': 'Census Tract 402; Appomattox County; Virginia',
#   'B01001_001E': 4755.0,
#   'B01001_002E': 2301.0,
#   'B01001_026E': 2454.0,
#   'state': '51',
#   'county': '011',
#   'tract': '040200'},
#  {'NAME': 'Census Tract 403; Appomattox County; Virginia',
#   'B01001_001E': 4021.0,
#   'B01001_002E': 2036.0,
#   'B01001_026E': 1985.0,
#   'state': '51',
#   'county': '011',
#   'tract': '040300'},
#  {'NAME': 'Census Tract 1001; Arlington County; Virginia',
#   'B01001_001E': 5339.0,
#   'B01001_002E': 2655.0,
#   'B01001_026E': 2684.0,
#   'state': '51',
#   'county': '013',
#   'tract': '100100'},
#  {'NAME': 'Census Tract 1002; Arlington County; Virginia',
#   'B01001_001E': 6987.0,
#   'B01001_002E': 3448.0,
#   'B01001_026E': 3539.0,
#   'state': '51',
#   'county': '013',
#   'tract': '100200'},
#  {'NAME': 'Census Tract 1003; Arlington County; Virginia',
#   'B01001_001E': 6845.0,
#   'B01001_002E': 3322.0,
#   'B01001_026E': 3523.0,
#   'state': '51',
#   'county': '013',
#   'tract': '100300'},
#  {'NAME': 'Census Tract 1004; Arlington County; Virginia',
#   'B01001_001E': 3877.0,
#   'B01001_002E': 1920.0,
#   'B01001_026E': 1957.0,
#   'state': '51',
#   'county': '013',
#   'tract': '100400'},
#  {'NAME': 'Census Tract 1005; Arlington County; Virginia',
#   'B01001_001E': 4461.0,
#   'B01001_002E': 2209.0,
#   'B01001_026E': 2252.0,
#   'state': '51',
#   'county': '013',
#   'tract': '100500'},
#  {'NAME': 'Census Tract 1006; Arlington County; Virginia',
#   'B01001_001E': 3411.0,
#   'B01001_002E': 1714.0,
#   'B01001_026E': 1697.0,
#   'state': '51',
#   'county': '013',
#   'tract': '100600'},
#  {'NAME': 'Census Tract 1007; Arlington County; Virginia',
#   'B01001_001E': 5585.0,
#   'B01001_002E': 2631.0,
#   'B01001_026E': 2954.0,
#   'state': '51',
#   'county': '013',
#   'tract': '100700'},
#  {'NAME': 'Census Tract 1008; Arlington County; Virginia',
#   'B01001_001E': 1511.0,
#   'B01001_002E': 775.0,
#   'B01001_026E': 736.0,
#   'state': '51',
#   'county': '013',
#   'tract': '100800'},
#  {'NAME': 'Census Tract 1009; Arlington County; Virginia',
#   'B01001_001E': 4627.0,
#   'B01001_002E': 2368.0,
#   'B01001_026E': 2259.0,
#   'state': '51',
#   'county': '013',
#   'tract': '100900'},
#  {'NAME': 'Census Tract 1010; Arlington County; Virginia',
#   'B01001_001E': 3382.0,
#   'B01001_002E': 1833.0,
#   'B01001_026E': 1549.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101000'},
#  {'NAME': 'Census Tract 1011; Arlington County; Virginia',
#   'B01001_001E': 6255.0,
#   'B01001_002E': 3179.0,
#   'B01001_026E': 3076.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101100'},
#  {'NAME': 'Census Tract 1012; Arlington County; Virginia',
#   'B01001_001E': 4091.0,
#   'B01001_002E': 2008.0,
#   'B01001_026E': 2083.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101200'},
#  {'NAME': 'Census Tract 1013; Arlington County; Virginia',
#   'B01001_001E': 7269.0,
#   'B01001_002E': 3970.0,
#   'B01001_026E': 3299.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101300'},
#  {'NAME': 'Census Tract 1014.01; Arlington County; Virginia',
#   'B01001_001E': 1635.0,
#   'B01001_002E': 772.0,
#   'B01001_026E': 863.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101401'},
#  {'NAME': 'Census Tract 1014.02; Arlington County; Virginia',
#   'B01001_001E': 2252.0,
#   'B01001_002E': 1259.0,
#   'B01001_026E': 993.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101402'},
#  {'NAME': 'Census Tract 1014.05; Arlington County; Virginia',
#   'B01001_001E': 1867.0,
#   'B01001_002E': 776.0,
#   'B01001_026E': 1091.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101405'},
#  {'NAME': 'Census Tract 1014.06; Arlington County; Virginia',
#   'B01001_001E': 3075.0,
#   'B01001_002E': 1855.0,
#   'B01001_026E': 1220.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101406'},
#  {'NAME': 'Census Tract 1014.07; Arlington County; Virginia',
#   'B01001_001E': 3621.0,
#   'B01001_002E': 2039.0,
#   'B01001_026E': 1582.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101407'},
#  {'NAME': 'Census Tract 1014.08; Arlington County; Virginia',
#   'B01001_001E': 695.0,
#   'B01001_002E': 409.0,
#   'B01001_026E': 286.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101408'},
#  {'NAME': 'Census Tract 1014.09; Arlington County; Virginia',
#   'B01001_001E': 2183.0,
#   'B01001_002E': 990.0,
#   'B01001_026E': 1193.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101409'},
#  {'NAME': 'Census Tract 1015.01; Arlington County; Virginia',
#   'B01001_001E': 3027.0,
#   'B01001_002E': 1565.0,
#   'B01001_026E': 1462.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101501'},
#  {'NAME': 'Census Tract 1015.02; Arlington County; Virginia',
#   'B01001_001E': 3114.0,
#   'B01001_002E': 1748.0,
#   'B01001_026E': 1366.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101502'},
#  {'NAME': 'Census Tract 1015.03; Arlington County; Virginia',
#   'B01001_001E': 1872.0,
#   'B01001_002E': 1086.0,
#   'B01001_026E': 786.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101503'},
#  {'NAME': 'Census Tract 1016.01; Arlington County; Virginia',
#   'B01001_001E': 1463.0,
#   'B01001_002E': 682.0,
#   'B01001_026E': 781.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101601'},
#  {'NAME': 'Census Tract 1016.02; Arlington County; Virginia',
#   'B01001_001E': 1758.0,
#   'B01001_002E': 792.0,
#   'B01001_026E': 966.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101602'},
#  {'NAME': 'Census Tract 1016.03; Arlington County; Virginia',
#   'B01001_001E': 4168.0,
#   'B01001_002E': 2094.0,
#   'B01001_026E': 2074.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101603'},
#  {'NAME': 'Census Tract 1017.01; Arlington County; Virginia',
#   'B01001_001E': 5019.0,
#   'B01001_002E': 2681.0,
#   'B01001_026E': 2338.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101701'},
#  {'NAME': 'Census Tract 1017.03; Arlington County; Virginia',
#   'B01001_001E': 2229.0,
#   'B01001_002E': 1125.0,
#   'B01001_026E': 1104.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101703'},
#  {'NAME': 'Census Tract 1017.04; Arlington County; Virginia',
#   'B01001_001E': 1873.0,
#   'B01001_002E': 1030.0,
#   'B01001_026E': 843.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101704'},
#  {'NAME': 'Census Tract 1017.05; Arlington County; Virginia',
#   'B01001_001E': 3366.0,
#   'B01001_002E': 1857.0,
#   'B01001_026E': 1509.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101705'},
#  {'NAME': 'Census Tract 1018.01; Arlington County; Virginia',
#   'B01001_001E': 2960.0,
#   'B01001_002E': 1603.0,
#   'B01001_026E': 1357.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101801'},
#  {'NAME': 'Census Tract 1018.03; Arlington County; Virginia',
#   'B01001_001E': 4766.0,
#   'B01001_002E': 2130.0,
#   'B01001_026E': 2636.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101803'},
#  {'NAME': 'Census Tract 1018.04; Arlington County; Virginia',
#   'B01001_001E': 2895.0,
#   'B01001_002E': 1502.0,
#   'B01001_026E': 1393.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101804'},
#  {'NAME': 'Census Tract 1018.05; Arlington County; Virginia',
#   'B01001_001E': 4043.0,
#   'B01001_002E': 2018.0,
#   'B01001_026E': 2025.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101805'},
#  {'NAME': 'Census Tract 1019; Arlington County; Virginia',
#   'B01001_001E': 2875.0,
#   'B01001_002E': 1433.0,
#   'B01001_026E': 1442.0,
#   'state': '51',
#   'county': '013',
#   'tract': '101900'},
#  {'NAME': 'Census Tract 1020.01; Arlington County; Virginia',
#   'B01001_001E': 3824.0,
#   'B01001_002E': 1758.0,
#   'B01001_026E': 2066.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102001'},
#  {'NAME': 'Census Tract 1020.02; Arlington County; Virginia',
#   'B01001_001E': 1292.0,
#   'B01001_002E': 636.0,
#   'B01001_026E': 656.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102002'},
#  {'NAME': 'Census Tract 1020.03; Arlington County; Virginia',
#   'B01001_001E': 4499.0,
#   'B01001_002E': 2140.0,
#   'B01001_026E': 2359.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102003'},
#  {'NAME': 'Census Tract 1021; Arlington County; Virginia',
#   'B01001_001E': 2497.0,
#   'B01001_002E': 1154.0,
#   'B01001_026E': 1343.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102100'},
#  {'NAME': 'Census Tract 1022; Arlington County; Virginia',
#   'B01001_001E': 8197.0,
#   'B01001_002E': 4321.0,
#   'B01001_026E': 3876.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102200'},
#  {'NAME': 'Census Tract 1023.01; Arlington County; Virginia',
#   'B01001_001E': 1421.0,
#   'B01001_002E': 728.0,
#   'B01001_026E': 693.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102301'},
#  {'NAME': 'Census Tract 1023.02; Arlington County; Virginia',
#   'B01001_001E': 4709.0,
#   'B01001_002E': 2360.0,
#   'B01001_026E': 2349.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102302'},
#  {'NAME': 'Census Tract 1024; Arlington County; Virginia',
#   'B01001_001E': 3608.0,
#   'B01001_002E': 1799.0,
#   'B01001_026E': 1809.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102400'},
#  {'NAME': 'Census Tract 1025; Arlington County; Virginia',
#   'B01001_001E': 5452.0,
#   'B01001_002E': 2861.0,
#   'B01001_026E': 2591.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102500'},
#  {'NAME': 'Census Tract 1026; Arlington County; Virginia',
#   'B01001_001E': 3668.0,
#   'B01001_002E': 1961.0,
#   'B01001_026E': 1707.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102600'},
#  {'NAME': 'Census Tract 1027.01; Arlington County; Virginia',
#   'B01001_001E': 3705.0,
#   'B01001_002E': 1776.0,
#   'B01001_026E': 1929.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102701'},
#  {'NAME': 'Census Tract 1027.02; Arlington County; Virginia',
#   'B01001_001E': 1937.0,
#   'B01001_002E': 1073.0,
#   'B01001_026E': 864.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102702'},
#  {'NAME': 'Census Tract 1028.02; Arlington County; Virginia',
#   'B01001_001E': 1284.0,
#   'B01001_002E': 635.0,
#   'B01001_026E': 649.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102802'},
#  {'NAME': 'Census Tract 1028.03; Arlington County; Virginia',
#   'B01001_001E': 2927.0,
#   'B01001_002E': 1516.0,
#   'B01001_026E': 1411.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102803'},
#  {'NAME': 'Census Tract 1028.04; Arlington County; Virginia',
#   'B01001_001E': 3972.0,
#   'B01001_002E': 2035.0,
#   'B01001_026E': 1937.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102804'},
#  {'NAME': 'Census Tract 1029.01; Arlington County; Virginia',
#   'B01001_001E': 2883.0,
#   'B01001_002E': 1251.0,
#   'B01001_026E': 1632.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102901'},
#  {'NAME': 'Census Tract 1029.03; Arlington County; Virginia',
#   'B01001_001E': 1571.0,
#   'B01001_002E': 757.0,
#   'B01001_026E': 814.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102903'},
#  {'NAME': 'Census Tract 1029.04; Arlington County; Virginia',
#   'B01001_001E': 2721.0,
#   'B01001_002E': 1187.0,
#   'B01001_026E': 1534.0,
#   'state': '51',
#   'county': '013',
#   'tract': '102904'},
#  {'NAME': 'Census Tract 1030; Arlington County; Virginia',
#   'B01001_001E': 3569.0,
#   'B01001_002E': 1829.0,
#   'B01001_026E': 1740.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103000'},
#  {'NAME': 'Census Tract 1031; Arlington County; Virginia',
#   'B01001_001E': 5713.0,
#   'B01001_002E': 2663.0,
#   'B01001_026E': 3050.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103100'},
#  {'NAME': 'Census Tract 1032; Arlington County; Virginia',
#   'B01001_001E': 5793.0,
#   'B01001_002E': 2896.0,
#   'B01001_026E': 2897.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103200'},
#  {'NAME': 'Census Tract 1033; Arlington County; Virginia',
#   'B01001_001E': 2487.0,
#   'B01001_002E': 1132.0,
#   'B01001_026E': 1355.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103300'},
#  {'NAME': 'Census Tract 1034.01; Arlington County; Virginia',
#   'B01001_001E': 1205.0,
#   'B01001_002E': 1036.0,
#   'B01001_026E': 169.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103401'},
#  {'NAME': 'Census Tract 1034.03; Arlington County; Virginia',
#   'B01001_001E': 1401.0,
#   'B01001_002E': 920.0,
#   'B01001_026E': 481.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103403'},
#  {'NAME': 'Census Tract 1034.04; Arlington County; Virginia',
#   'B01001_001E': 1284.0,
#   'B01001_002E': 731.0,
#   'B01001_026E': 553.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103404'},
#  {'NAME': 'Census Tract 1034.05; Arlington County; Virginia',
#   'B01001_001E': 3852.0,
#   'B01001_002E': 1772.0,
#   'B01001_026E': 2080.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103405'},
#  {'NAME': 'Census Tract 1035.01; Arlington County; Virginia',
#   'B01001_001E': 3368.0,
#   'B01001_002E': 1763.0,
#   'B01001_026E': 1605.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103501'},
#  {'NAME': 'Census Tract 1035.03; Arlington County; Virginia',
#   'B01001_001E': 4754.0,
#   'B01001_002E': 1940.0,
#   'B01001_026E': 2814.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103503'},
#  {'NAME': 'Census Tract 1035.04; Arlington County; Virginia',
#   'B01001_001E': 3227.0,
#   'B01001_002E': 1687.0,
#   'B01001_026E': 1540.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103504'},
#  {'NAME': 'Census Tract 1035.05; Arlington County; Virginia',
#   'B01001_001E': 3335.0,
#   'B01001_002E': 1580.0,
#   'B01001_026E': 1755.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103505'},
#  {'NAME': 'Census Tract 1036.01; Arlington County; Virginia',
#   'B01001_001E': 2555.0,
#   'B01001_002E': 1308.0,
#   'B01001_026E': 1247.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103601'},
#  {'NAME': 'Census Tract 1036.02; Arlington County; Virginia',
#   'B01001_001E': 1391.0,
#   'B01001_002E': 718.0,
#   'B01001_026E': 673.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103602'},
#  {'NAME': 'Census Tract 1037; Arlington County; Virginia',
#   'B01001_001E': 2493.0,
#   'B01001_002E': 1202.0,
#   'B01001_026E': 1291.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103700'},
#  {'NAME': 'Census Tract 1038; Arlington County; Virginia',
#   'B01001_001E': 4850.0,
#   'B01001_002E': 2427.0,
#   'B01001_026E': 2423.0,
#   'state': '51',
#   'county': '013',
#   'tract': '103800'},
#  {'NAME': 'Census Tract 9801; Arlington County; Virginia',
#   'B01001_001E': 5.0,
#   'B01001_002E': 0.0,
#   'B01001_026E': 5.0,
#   'state': '51',
#   'county': '013',
#   'tract': '980100'},
#  {'NAME': 'Census Tract 9802; Arlington County; Virginia',
#   'B01001_001E': 0.0,
#   'B01001_002E': 0.0,
#   'B01001_026E': 0.0,
#   'state': '51',
#   'county': '013',
#   'tract': '980200'},
#  {'NAME': 'Census Tract 701; Augusta County; Virginia',
#   'B01001_001E': 4801.0,
#   'B01001_002E': 3390.0,
#   'B01001_026E': 1411.0,
#   'state': '51',
#   'county': '015',
#   'tract': '070100'},
#  {'NAME': 'Census Tract 702; Augusta County; Virginia',
#   'B01001_001E': 3922.0,
#   'B01001_002E': 1986.0,
#   'B01001_026E': 1936.0,
#   'state': '51',
#   'county': '015',
#   'tract': '070200'},
#  {'NAME': 'Census Tract 703; Augusta County; Virginia',
#   'B01001_001E': 6854.0,
#   'B01001_002E': 3391.0,
#   'B01001_026E': 3463.0,
#   'state': '51',
#   'county': '015',
#   'tract': '070300'},
#  {'NAME': 'Census Tract 704; Augusta County; Virginia',
#   'B01001_001E': 5662.0,
#   'B01001_002E': 2706.0,
#   'B01001_026E': 2956.0,
#   'state': '51',
#   'county': '015',
#   'tract': '070400'},
#  {'NAME': 'Census Tract 705; Augusta County; Virginia',
#   'B01001_001E': 5041.0,
#   'B01001_002E': 2624.0,
#   'B01001_026E': 2417.0,
#   'state': '51',
#   'county': '015',
#   'tract': '070500'},
#  {'NAME': 'Census Tract 706.01; Augusta County; Virginia',
#   'B01001_001E': 2849.0,
#   'B01001_002E': 1431.0,
#   'B01001_026E': 1418.0,
#   'state': '51',
#   'county': '015',
#   'tract': '070601'},
#  {'NAME': 'Census Tract 706.02; Augusta County; Virginia',
#   'B01001_001E': 3248.0,
#   'B01001_002E': 1284.0,
#   'B01001_026E': 1964.0,
#   'state': '51',
#   'county': '015',
#   'tract': '070602'},
#  {'NAME': 'Census Tract 706.03; Augusta County; Virginia',
#   'B01001_001E': 4192.0,
#   'B01001_002E': 2081.0,
#   'B01001_026E': 2111.0,
#   'state': '51',
#   'county': '015',
#   'tract': '070603'},
#  {'NAME': 'Census Tract 707.01; Augusta County; Virginia',
#   'B01001_001E': 4951.0,
#   'B01001_002E': 2797.0,
#   'B01001_026E': 2154.0,
#   'state': '51',
#   'county': '015',
#   'tract': '070701'},
#  {'NAME': 'Census Tract 707.02; Augusta County; Virginia',
#   'B01001_001E': 2563.0,
#   'B01001_002E': 1295.0,
#   'B01001_026E': 1268.0,
#   'state': '51',
#   'county': '015',
#   'tract': '070702'},
#  {'NAME': 'Census Tract 708.01; Augusta County; Virginia',
#   'B01001_001E': 2087.0,
#   'B01001_002E': 1147.0,
#   'B01001_026E': 940.0,
#   'state': '51',
#   'county': '015',
#   'tract': '070801'},
#  {'NAME': 'Census Tract 708.02; Augusta County; Virginia',
#   'B01001_001E': 4254.0,
#   'B01001_002E': 2224.0,
#   'B01001_026E': 2030.0,
#   'state': '51',
#   'county': '015',
#   'tract': '070802'},
#  {'NAME': 'Census Tract 709; Augusta County; Virginia',
#   'B01001_001E': 5209.0,
#   'B01001_002E': 2440.0,
#   'B01001_026E': 2769.0,
#   'state': '51',
#   'county': '015',
#   'tract': '070900'},
#  {'NAME': 'Census Tract 710; Augusta County; Virginia',
#   'B01001_001E': 5307.0,
#   'B01001_002E': 2696.0,
#   'B01001_026E': 2611.0,
#   'state': '51',
#   'county': '015',
#   'tract': '071000'},
#  {'NAME': 'Census Tract 711.01; Augusta County; Virginia',
#   'B01001_001E': 4124.0,
#   'B01001_002E': 1930.0,
#   'B01001_026E': 2194.0,
#   'state': '51',
#   'county': '015',
#   'tract': '071101'},
#  {'NAME': 'Census Tract 711.02; Augusta County; Virginia',
#   'B01001_001E': 6479.0,
#   'B01001_002E': 3378.0,
#   'B01001_026E': 3101.0,
#   'state': '51',
#   'county': '015',
#   'tract': '071102'},
#  {'NAME': 'Census Tract 712.01; Augusta County; Virginia',
#   'B01001_001E': 2090.0,
#   'B01001_002E': 1060.0,
#   'B01001_026E': 1030.0,
#   'state': '51',
#   'county': '015',
#   'tract': '071201'},
#  {'NAME': 'Census Tract 712.02; Augusta County; Virginia',
#   'B01001_001E': 3800.0,
#   'B01001_002E': 1687.0,
#   'B01001_026E': 2113.0,
#   'state': '51',
#   'county': '015',
#   'tract': '071202'},
#  {'NAME': 'Census Tract 9201.01; Bath County; Virginia',
#   'B01001_001E': 1759.0,
#   'B01001_002E': 995.0,
#   'B01001_026E': 764.0,
#   'state': '51',
#   'county': '017',
#   'tract': '920101'},
#  {'NAME': 'Census Tract 9201.02; Bath County; Virginia',
#   'B01001_001E': 2418.0,
#   'B01001_002E': 1078.0,
#   'B01001_026E': 1340.0,
#   'state': '51',
#   'county': '017',
#   'tract': '920102'},
#  {'NAME': 'Census Tract 301.01; Bedford County; Virginia',
#   'B01001_001E': 7814.0,
#   'B01001_002E': 4046.0,
#   'B01001_026E': 3768.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030101'},
#  {'NAME': 'Census Tract 301.03; Bedford County; Virginia',
#   'B01001_001E': 8034.0,
#   'B01001_002E': 3806.0,
#   'B01001_026E': 4228.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030103'},
#  {'NAME': 'Census Tract 301.04; Bedford County; Virginia',
#   'B01001_001E': 4610.0,
#   'B01001_002E': 2152.0,
#   'B01001_026E': 2458.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030104'},
#  {'NAME': 'Census Tract 302.02; Bedford County; Virginia',
#   'B01001_001E': 5411.0,
#   'B01001_002E': 2821.0,
#   'B01001_026E': 2590.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030202'},
#  {'NAME': 'Census Tract 302.03; Bedford County; Virginia',
#   'B01001_001E': 4802.0,
#   'B01001_002E': 2493.0,
#   'B01001_026E': 2309.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030203'},
#  {'NAME': 'Census Tract 302.04; Bedford County; Virginia',
#   'B01001_001E': 3997.0,
#   'B01001_002E': 1969.0,
#   'B01001_026E': 2028.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030204'},
#  {'NAME': 'Census Tract 303; Bedford County; Virginia',
#   'B01001_001E': 3666.0,
#   'B01001_002E': 1901.0,
#   'B01001_026E': 1765.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030300'},
#  {'NAME': 'Census Tract 304.01; Bedford County; Virginia',
#   'B01001_001E': 3189.0,
#   'B01001_002E': 1584.0,
#   'B01001_026E': 1605.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030401'},
#  {'NAME': 'Census Tract 304.03; Bedford County; Virginia',
#   'B01001_001E': 3299.0,
#   'B01001_002E': 1570.0,
#   'B01001_026E': 1729.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030403'},
#  {'NAME': 'Census Tract 304.04; Bedford County; Virginia',
#   'B01001_001E': 4209.0,
#   'B01001_002E': 2130.0,
#   'B01001_026E': 2079.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030404'},
#  {'NAME': 'Census Tract 305.01; Bedford County; Virginia',
#   'B01001_001E': 4152.0,
#   'B01001_002E': 2072.0,
#   'B01001_026E': 2080.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030501'},
#  {'NAME': 'Census Tract 305.03; Bedford County; Virginia',
#   'B01001_001E': 2794.0,
#   'B01001_002E': 1328.0,
#   'B01001_026E': 1466.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030503'},
#  {'NAME': 'Census Tract 305.04; Bedford County; Virginia',
#   'B01001_001E': 2575.0,
#   'B01001_002E': 1275.0,
#   'B01001_026E': 1300.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030504'},
#  {'NAME': 'Census Tract 306.01; Bedford County; Virginia',
#   'B01001_001E': 2989.0,
#   'B01001_002E': 1504.0,
#   'B01001_026E': 1485.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030601'},
#  {'NAME': 'Census Tract 306.02; Bedford County; Virginia',
#   'B01001_001E': 3288.0,
#   'B01001_002E': 1632.0,
#   'B01001_026E': 1656.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030602'},
#  {'NAME': 'Census Tract 306.03; Bedford County; Virginia',
#   'B01001_001E': 2490.0,
#   'B01001_002E': 1318.0,
#   'B01001_026E': 1172.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030603'},
#  {'NAME': 'Census Tract 306.04; Bedford County; Virginia',
#   'B01001_001E': 2517.0,
#   'B01001_002E': 1329.0,
#   'B01001_026E': 1188.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030604'},
#  {'NAME': 'Census Tract 306.05; Bedford County; Virginia',
#   'B01001_001E': 3595.0,
#   'B01001_002E': 1728.0,
#   'B01001_026E': 1867.0,
#   'state': '51',
#   'county': '019',
#   'tract': '030605'},
#  {'NAME': 'Census Tract 501.01; Bedford County; Virginia',
#   'B01001_001E': 3249.0,
#   'B01001_002E': 1264.0,
#   'B01001_026E': 1985.0,
#   'state': '51',
#   'county': '019',
#   'tract': '050101'},
#  {'NAME': 'Census Tract 501.02; Bedford County; Virginia',
#   'B01001_001E': 3081.0,
#   'B01001_002E': 1530.0,
#   'B01001_026E': 1551.0,
#   'state': '51',
#   'county': '019',
#   'tract': '050102'},
#  {'NAME': 'Census Tract 401; Bland County; Virginia',
#   'B01001_001E': 3938.0,
#   'B01001_002E': 2311.0,
#   'B01001_026E': 1627.0,
#   'state': '51',
#   'county': '021',
#   'tract': '040100'},
#  {'NAME': 'Census Tract 402; Bland County; Virginia',
#   'B01001_001E': 2303.0,
#   'B01001_002E': 1229.0,
#   'B01001_026E': 1074.0,
#   'state': '51',
#   'county': '021',
#   'tract': '040200'},
#  {'NAME': 'Census Tract 401; Botetourt County; Virginia',
#   'B01001_001E': 3315.0,
#   'B01001_002E': 1670.0,
#   'B01001_026E': 1645.0,
#   'state': '51',
#   'county': '023',
#   'tract': '040100'},
#  {'NAME': 'Census Tract 402; Botetourt County; Virginia',
#   'B01001_001E': 3982.0,
#   'B01001_002E': 2036.0,
#   'B01001_026E': 1946.0,
#   'state': '51',
#   'county': '023',
#   'tract': '040200'},
#  {'NAME': 'Census Tract 403.01; Botetourt County; Virginia',
#   'B01001_001E': 2929.0,
#   'B01001_002E': 1563.0,
#   'B01001_026E': 1366.0,
#   'state': '51',
#   'county': '023',
#   'tract': '040301'},
#  {'NAME': 'Census Tract 403.03; Botetourt County; Virginia',
#   'B01001_001E': 4469.0,
#   'B01001_002E': 2243.0,
#   'B01001_026E': 2226.0,
#   'state': '51',
#   'county': '023',
#   'tract': '040303'},
#  {'NAME': 'Census Tract 403.04; Botetourt County; Virginia',
#   'B01001_001E': 4039.0,
#   'B01001_002E': 2024.0,
#   'B01001_026E': 2015.0,
#   'state': '51',
#   'county': '023',
#   'tract': '040304'},
#  {'NAME': 'Census Tract 404.01; Botetourt County; Virginia',
#   'B01001_001E': 2405.0,
#   'B01001_002E': 1241.0,
#   'B01001_026E': 1164.0,
#   'state': '51',
#   'county': '023',
#   'tract': '040401'},
#  {'NAME': 'Census Tract 404.02; Botetourt County; Virginia',
#   'B01001_001E': 5093.0,
#   'B01001_002E': 2393.0,
#   'B01001_026E': 2700.0,
#   'state': '51',
#   'county': '023',
#   'tract': '040402'},
#  {'NAME': 'Census Tract 405.01; Botetourt County; Virginia',
#   'B01001_001E': 5969.0,
#   'B01001_002E': 3065.0,
#   'B01001_026E': 2904.0,
#   'state': '51',
#   'county': '023',
#   'tract': '040501'},
#  {'NAME': 'Census Tract 405.02; Botetourt County; Virginia',
#   'B01001_001E': 1533.0,
#   'B01001_002E': 585.0,
#   'B01001_026E': 948.0,
#   'state': '51',
#   'county': '023',
#   'tract': '040502'},
#  {'NAME': 'Census Tract 9301; Brunswick County; Virginia',
#   'B01001_001E': 2886.0,
#   'B01001_002E': 1337.0,
#   'B01001_026E': 1549.0,
#   'state': '51',
#   'county': '025',
#   'tract': '930100'},
#  {'NAME': 'Census Tract 9302.01; Brunswick County; Virginia',
#   'B01001_001E': 2068.0,
#   'B01001_002E': 1088.0,
#   'B01001_026E': 980.0,
#   'state': '51',
#   'county': '025',
#   'tract': '930201'},
#  {'NAME': 'Census Tract 9302.02; Brunswick County; Virginia',
#   'B01001_001E': 1693.0,
#   'B01001_002E': 1558.0,
#   'B01001_026E': 135.0,
#   'state': '51',
#   'county': '025',
#   'tract': '930202'},
#  {'NAME': 'Census Tract 9302.03; Brunswick County; Virginia',
#   'B01001_001E': 4316.0,
#   'B01001_002E': 2169.0,
#   'B01001_026E': 2147.0,
#   'state': '51',
#   'county': '025',
#   'tract': '930203'},
#  {'NAME': 'Census Tract 9303.01; Brunswick County; Virginia',
#   'B01001_001E': 1761.0,
#   'B01001_002E': 809.0,
#   'B01001_026E': 952.0,
#   'state': '51',
#   'county': '025',
#   'tract': '930301'},
#  {'NAME': 'Census Tract 9303.02; Brunswick County; Virginia',
#   'B01001_001E': 3241.0,
#   'B01001_002E': 1552.0,
#   'B01001_026E': 1689.0,
#   'state': '51',
#   'county': '025',
#   'tract': '930302'},
#  {'NAME': 'Census Tract 101; Buchanan County; Virginia',
#   'B01001_001E': 4651.0,
#   'B01001_002E': 2055.0,
#   'B01001_026E': 2596.0,
#   'state': '51',
#   'county': '027',
#   'tract': '010100'},
#  {'NAME': 'Census Tract 102; Buchanan County; Virginia',
#   'B01001_001E': 2539.0,
#   'B01001_002E': 1392.0,
#   'B01001_026E': 1147.0,
#   'state': '51',
#   'county': '027',
#   'tract': '010200'},
#  {'NAME': 'Census Tract 103; Buchanan County; Virginia',
#   'B01001_001E': 2831.0,
#   'B01001_002E': 1603.0,
#   'B01001_026E': 1228.0,
#   'state': '51',
#   'county': '027',
#   'tract': '010300'},
#  {'NAME': 'Census Tract 104; Buchanan County; Virginia',
#   'B01001_001E': 1842.0,
#   'B01001_002E': 975.0,
#   'B01001_026E': 867.0,
#   'state': '51',
#   'county': '027',
#   'tract': '010400'},
#  {'NAME': 'Census Tract 105; Buchanan County; Virginia',
#   'B01001_001E': 1033.0,
#   'B01001_002E': 558.0,
#   'B01001_026E': 475.0,
#   'state': '51',
#   'county': '027',
#   'tract': '010500'},
#  {'NAME': 'Census Tract 106; Buchanan County; Virginia',
#   'B01001_001E': 3378.0,
#   'B01001_002E': 1930.0,
#   'B01001_026E': 1448.0,
#   'state': '51',
#   'county': '027',
#   'tract': '010600'},
#  {'NAME': 'Census Tract 107; Buchanan County; Virginia',
#   'B01001_001E': 3972.0,
#   'B01001_002E': 1991.0,
#   'B01001_026E': 1981.0,
#   'state': '51',
#   'county': '027',
#   'tract': '010700'},
#  {'NAME': 'Census Tract 9301.01; Buckingham County; Virginia',
#   'B01001_001E': 3453.0,
#   'B01001_002E': 1519.0,
#   'B01001_026E': 1934.0,
#   'state': '51',
#   'county': '029',
#   'tract': '930101'},
#  {'NAME': 'Census Tract 9301.02; Buckingham County; Virginia',
#   'B01001_001E': 3238.0,
#   'B01001_002E': 1709.0,
#   'B01001_026E': 1529.0,
#   'state': '51',
#   'county': '029',
#   'tract': '930102'},
#  {'NAME': 'Census Tract 9302.01; Buckingham County; Virginia',
#   'B01001_001E': 5612.0,
#   'B01001_002E': 3897.0,
#   'B01001_026E': 1715.0,
#   'state': '51',
#   'county': '029',
#   'tract': '930201'},
#  {'NAME': 'Census Tract 9302.02; Buckingham County; Virginia',
#   'B01001_001E': 4566.0,
#   'B01001_002E': 2280.0,
#   'B01001_026E': 2286.0,
#   'state': '51',
#   'county': '029',
#   'tract': '930202'},
#  {'NAME': 'Census Tract 201.01; Campbell County; Virginia',
#   'B01001_001E': 5460.0,
#   'B01001_002E': 2710.0,
#   'B01001_026E': 2750.0,
#   'state': '51',
#   'county': '031',
#   'tract': '020101'},
#  {'NAME': 'Census Tract 201.02; Campbell County; Virginia',
#   'B01001_001E': 4646.0,
#   'B01001_002E': 2268.0,
#   'B01001_026E': 2378.0,
#   'state': '51',
#   'county': '031',
#   'tract': '020102'},
#  {'NAME': 'Census Tract 202; Campbell County; Virginia',
#   'B01001_001E': 5437.0,
#   'B01001_002E': 2968.0,
#   'B01001_026E': 2469.0,
#   'state': '51',
#   'county': '031',
#   'tract': '020200'},
#  {'NAME': 'Census Tract 203; Campbell County; Virginia',
#   'B01001_001E': 3799.0,
#   'B01001_002E': 1688.0,
#   'B01001_026E': 2111.0,
#   'state': '51',
#   'county': '031',
#   'tract': '020300'},
#  {'NAME': 'Census Tract 204.01; Campbell County; Virginia',
#   'B01001_001E': 4895.0,
#   'B01001_002E': 2464.0,
#   'B01001_026E': 2431.0,
#   'state': '51',
#   'county': '031',
#   'tract': '020401'},
#  {'NAME': 'Census Tract 204.02; Campbell County; Virginia',
#   'B01001_001E': 3431.0,
#   'B01001_002E': 1635.0,
#   'B01001_026E': 1796.0,
#   'state': '51',
#   'county': '031',
#   'tract': '020402'},
#  {'NAME': 'Census Tract 204.03; Campbell County; Virginia',
#   'B01001_001E': 5828.0,
#   'B01001_002E': 2995.0,
#   'B01001_026E': 2833.0,
#   'state': '51',
#   'county': '031',
#   'tract': '020403'},
#  {'NAME': 'Census Tract 205; Campbell County; Virginia',
#   'B01001_001E': 7744.0,
#   'B01001_002E': 3959.0,
#   'B01001_026E': 3785.0,
#   'state': '51',
#   'county': '031',
#   'tract': '020500'},
#  {'NAME': 'Census Tract 206; Campbell County; Virginia',
#   'B01001_001E': 3686.0,
#   'B01001_002E': 1592.0,
#   'B01001_026E': 2094.0,
#   'state': '51',
#   'county': '031',
#   'tract': '020600'},
#  {'NAME': 'Census Tract 207; Campbell County; Virginia',
#   'B01001_001E': 3370.0,
#   'B01001_002E': 1704.0,
#   'B01001_026E': 1666.0,
#   'state': '51',
#   'county': '031',
#   'tract': '020700'},
#  {'NAME': 'Census Tract 208; Campbell County; Virginia',
#   'B01001_001E': 2900.0,
#   'B01001_002E': 1247.0,
#   'B01001_026E': 1653.0,
#   'state': '51',
#   'county': '031',
#   'tract': '020800'},
#  {'NAME': 'Census Tract 209; Campbell County; Virginia',
#   'B01001_001E': 4322.0,
#   'B01001_002E': 1861.0,
#   'B01001_026E': 2461.0,
#   'state': '51',
#   'county': '031',
#   'tract': '020900'},
#  {'NAME': 'Census Tract 301; Caroline County; Virginia',
#   'B01001_001E': 5348.0,
#   'B01001_002E': 3138.0,
#   'B01001_026E': 2210.0,
#   'state': '51',
#   'county': '033',
#   'tract': '030100'},
#  {'NAME': 'Census Tract 302.01; Caroline County; Virginia',
#   'B01001_001E': 3451.0,
#   'B01001_002E': 1804.0,
#   'B01001_026E': 1647.0,
#   'state': '51',
#   'county': '033',
#   'tract': '030201'},
#  {'NAME': 'Census Tract 302.02; Caroline County; Virginia',
#   'B01001_001E': 1684.0,
#   'B01001_002E': 825.0,
#   'B01001_026E': 859.0,
#   'state': '51',
#   'county': '033',
#   'tract': '030202'},
#  {'NAME': 'Census Tract 303; Caroline County; Virginia',
#   'B01001_001E': 3367.0,
#   'B01001_002E': 1592.0,
#   'B01001_026E': 1775.0,
#   'state': '51',
#   'county': '033',
#   'tract': '030300'},
#  {'NAME': 'Census Tract 304; Caroline County; Virginia',
#   'B01001_001E': 2154.0,
#   'B01001_002E': 1132.0,
#   'B01001_026E': 1022.0,
#   'state': '51',
#   'county': '033',
#   'tract': '030400'},
#  {'NAME': 'Census Tract 305.01; Caroline County; Virginia',
#   'B01001_001E': 4304.0,
#   'B01001_002E': 1853.0,
#   'B01001_026E': 2451.0,
#   'state': '51',
#   'county': '033',
#   'tract': '030501'},
#  {'NAME': 'Census Tract 305.02; Caroline County; Virginia',
#   'B01001_001E': 4957.0,
#   'B01001_002E': 2462.0,
#   'B01001_026E': 2495.0,
#   'state': '51',
#   'county': '033',
#   'tract': '030502'},
#  {'NAME': 'Census Tract 305.03; Caroline County; Virginia',
#   'B01001_001E': 2326.0,
#   'B01001_002E': 1028.0,
#   'B01001_026E': 1298.0,
#   'state': '51',
#   'county': '033',
#   'tract': '030503'},
#  {'NAME': 'Census Tract 306; Caroline County; Virginia',
#   'B01001_001E': 3590.0,
#   'B01001_002E': 1623.0,
#   'B01001_026E': 1967.0,
#   'state': '51',
#   'county': '033',
#   'tract': '030600'},
#  {'NAME': 'Census Tract 801; Carroll County; Virginia',
#   'B01001_001E': 3740.0,
#   'B01001_002E': 1947.0,
#   'B01001_026E': 1793.0,
#   'state': '51',
#   'county': '035',
#   'tract': '080100'},
#  {'NAME': 'Census Tract 802; Carroll County; Virginia',
#   'B01001_001E': 4512.0,
#   'B01001_002E': 2377.0,
#   'B01001_026E': 2135.0,
#   'state': '51',
#   'county': '035',
#   'tract': '080200'},
#  {'NAME': 'Census Tract 803; Carroll County; Virginia',
#   'B01001_001E': 4534.0,
#   'B01001_002E': 1940.0,
#   'B01001_026E': 2594.0,
#   'state': '51',
#   'county': '035',
#   'tract': '080300'},
#  {'NAME': 'Census Tract 804.01; Carroll County; Virginia',
#   'B01001_001E': 2791.0,
#   'B01001_002E': 1322.0,
#   'B01001_026E': 1469.0,
#   'state': '51',
#   'county': '035',
#   'tract': '080401'},
#  {'NAME': 'Census Tract 804.02; Carroll County; Virginia',
#   'B01001_001E': 2110.0,
#   'B01001_002E': 1005.0,
#   'B01001_026E': 1105.0,
#   'state': '51',
#   'county': '035',
#   'tract': '080402'},
#  {'NAME': 'Census Tract 805.01; Carroll County; Virginia',
#   'B01001_001E': 2885.0,
#   'B01001_002E': 1550.0,
#   'B01001_026E': 1335.0,
#   'state': '51',
#   'county': '035',
#   'tract': '080501'},
#  {'NAME': 'Census Tract 805.02; Carroll County; Virginia',
#   'B01001_001E': 2390.0,
#   'B01001_002E': 867.0,
#   'B01001_026E': 1523.0,
#   'state': '51',
#   'county': '035',
#   'tract': '080502'},
#  {'NAME': 'Census Tract 806.01; Carroll County; Virginia',
#   'B01001_001E': 1833.0,
#   'B01001_002E': 960.0,
#   'B01001_026E': 873.0,
#   'state': '51',
#   'county': '035',
#   'tract': '080601'},
#  {'NAME': 'Census Tract 806.03; Carroll County; Virginia',
#   'B01001_001E': 2595.0,
#   'B01001_002E': 1457.0,
#   'B01001_026E': 1138.0,
#   'state': '51',
#   'county': '035',
#   'tract': '080603'},
#  {'NAME': 'Census Tract 806.04; Carroll County; Virginia',
#   'B01001_001E': 1736.0,
#   'B01001_002E': 910.0,
#   'B01001_026E': 826.0,
#   'state': '51',
#   'county': '035',
#   'tract': '080604'},
#  {'NAME': 'Census Tract 6001; Charles City County; Virginia',
#   'B01001_001E': 2722.0,
#   'B01001_002E': 1384.0,
#   'B01001_026E': 1338.0,
#   'state': '51',
#   'county': '036',
#   'tract': '600100'},
#  {'NAME': 'Census Tract 6002; Charles City County; Virginia',
#   'B01001_001E': 2374.0,
#   'B01001_002E': 1158.0,
#   'B01001_026E': 1216.0,
#   'state': '51',
#   'county': '036',
#   'tract': '600200'},
#  {'NAME': 'Census Tract 6003; Charles City County; Virginia',
#   'B01001_001E': 1664.0,
#   'B01001_002E': 820.0,
#   'B01001_026E': 844.0,
#   'state': '51',
#   'county': '036',
#   'tract': '600300'},
#  {'NAME': 'Census Tract 9301.01; Charlotte County; Virginia',
#   'B01001_001E': 3062.0,
#   'B01001_002E': 1408.0,
#   'B01001_026E': 1654.0,
#   'state': '51',
#   'county': '037',
#   'tract': '930101'},
#  {'NAME': 'Census Tract 9301.02; Charlotte County; Virginia',
#   'B01001_001E': 2214.0,
#   'B01001_002E': 1038.0,
#   'B01001_026E': 1176.0,
#   'state': '51',
#   'county': '037',
#   'tract': '930102'},
#  {'NAME': 'Census Tract 9302; Charlotte County; Virginia',
#   'B01001_001E': 2983.0,
#   'B01001_002E': 1632.0,
#   'B01001_026E': 1351.0,
#   'state': '51',
#   'county': '037',
#   'tract': '930200'},
#  {'NAME': 'Census Tract 9303; Charlotte County; Virginia',
#   'B01001_001E': 3304.0,
#   'B01001_002E': 1787.0,
#   'B01001_026E': 1517.0,
#   'state': '51',
#   'county': '037',
#   'tract': '930300'},
#  {'NAME': 'Census Tract 1001.06; Chesterfield County; Virginia',
#   'B01001_001E': 3851.0,
#   'B01001_002E': 2039.0,
#   'B01001_026E': 1812.0,
#   'state': '51',
#   'county': '041',
#   'tract': '100106'},
#  {'NAME': 'Census Tract 1001.07; Chesterfield County; Virginia',
#   'B01001_001E': 2511.0,
#   'B01001_002E': 1186.0,
#   'B01001_026E': 1325.0,
#   'state': '51',
#   'county': '041',
#   'tract': '100107'},
#  {'NAME': 'Census Tract 1002.06; Chesterfield County; Virginia',
#   'B01001_001E': 6513.0,
#   'B01001_002E': 3135.0,
#   'B01001_026E': 3378.0,
#   'state': '51',
#   'county': '041',
#   'tract': '100206'},
#  {'NAME': 'Census Tract 1002.08; Chesterfield County; Virginia',
#   'B01001_001E': 2363.0,
#   'B01001_002E': 1040.0,
#   'B01001_026E': 1323.0,
#   'state': '51',
#   'county': '041',
#   'tract': '100208'},
#  {'NAME': 'Census Tract 1002.09; Chesterfield County; Virginia',
#   'B01001_001E': 6499.0,
#   'B01001_002E': 2959.0,
#   'B01001_026E': 3540.0,
#   'state': '51',
#   'county': '041',
#   'tract': '100209'},
#  {'NAME': 'Census Tract 1002.10; Chesterfield County; Virginia',
#   'B01001_001E': 2007.0,
#   'B01001_002E': 971.0,
# ...
#  {'NAME': 'Census Tract 6105.05; Loudoun County; Virginia',
#   'B01001_001E': 6496.0,
#   'B01001_002E': 3312.0,
#   'B01001_026E': 3184.0,
#   'state': '51',
#   'county': '107',
#   'tract': '610505'},
#  {'NAME': 'Census Tract 6105.06; Loudoun County; Virginia',
#   'B01001_001E': 5851.0,
#   'B01001_002E': 2824.0,
#   'B01001_026E': 3027.0,
#   'state': '51',
#   'county': '107',
#   'tract': '610506'},
#  {'NAME': 'Census Tract 6105.07; Loudoun County; Virginia',
#   'B01001_001E': 5958.0,
#   'B01001_002E': 3024.0,
#   'B01001_026E': 2934.0,
#   'state': '51',
#   'county': '107',
#   'tract': '610507'},
#  {'NAME': 'Census Tract 6106.01; Loudoun County; Virginia',
#   'B01001_001E': 7317.0,
#   'B01001_002E': 3640.0,
#   'B01001_026E': 3677.0,
#   'state': '51',
#   'county': '107',
#   'tract': '610601'},
#  {'NAME': 'Census Tract 6106.02; Loudoun County; Virginia',
#   'B01001_001E': 2783.0,
#   'B01001_002E': 1401.0,
#   'B01001_026E': 1382.0,
#   'state': '51',
#   'county': '107',
#   'tract': '610602'},
#  {'NAME': 'Census Tract 6106.03; Loudoun County; Virginia',
#   'B01001_001E': 3738.0,
#   'B01001_002E': 1788.0,
#   'B01001_026E': 1950.0,
#   'state': '51',
#   'county': '107',
#   'tract': '610603'},
#  {'NAME': 'Census Tract 6106.04; Loudoun County; Virginia',
#   'B01001_001E': 6781.0,
#   'B01001_002E': 3647.0,
#   'B01001_026E': 3134.0,
#   'state': '51',
#   'county': '107',
#   'tract': '610604'},
#  {'NAME': 'Census Tract 6107.01; Loudoun County; Virginia',
#   'B01001_001E': 5495.0,
#   'B01001_002E': 2718.0,
#   'B01001_026E': 2777.0,
#   'state': '51',
#   'county': '107',
#   'tract': '610701'},
#  {'NAME': 'Census Tract 6107.02; Loudoun County; Virginia',
#   'B01001_001E': 7529.0,
#   'B01001_002E': 4128.0,
#   'B01001_026E': 3401.0,
#   'state': '51',
#   'county': '107',
#   'tract': '610702'},
#  {'NAME': 'Census Tract 6107.03; Loudoun County; Virginia',
#   'B01001_001E': 5160.0,
#   'B01001_002E': 2581.0,
#   'B01001_026E': 2579.0,
#   'state': '51',
#   'county': '107',
#   'tract': '610703'},
#  {'NAME': 'Census Tract 6108; Loudoun County; Virginia',
#   'B01001_001E': 7420.0,
#   'B01001_002E': 3372.0,
#   'B01001_026E': 4048.0,
#   'state': '51',
#   'county': '107',
#   'tract': '610800'},
#  {'NAME': 'Census Tract 6109; Loudoun County; Virginia',
#   'B01001_001E': 2661.0,
#   'B01001_002E': 1202.0,
#   'B01001_026E': 1459.0,
#   'state': '51',
#   'county': '107',
#   'tract': '610900'},
#  {'NAME': 'Census Tract 6110.02; Loudoun County; Virginia',
#   'B01001_001E': 5478.0,
#   'B01001_002E': 2661.0,
#   'B01001_026E': 2817.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611002'},
#  {'NAME': 'Census Tract 6110.04; Loudoun County; Virginia',
#   'B01001_001E': 8318.0,
#   'B01001_002E': 4254.0,
#   'B01001_026E': 4064.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611004'},
#  {'NAME': 'Census Tract 6110.05; Loudoun County; Virginia',
#   'B01001_001E': 5162.0,
#   'B01001_002E': 2415.0,
#   'B01001_026E': 2747.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611005'},
#  {'NAME': 'Census Tract 6110.06; Loudoun County; Virginia',
#   'B01001_001E': 5577.0,
#   'B01001_002E': 2940.0,
#   'B01001_026E': 2637.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611006'},
#  {'NAME': 'Census Tract 6110.09; Loudoun County; Virginia',
#   'B01001_001E': 5670.0,
#   'B01001_002E': 2772.0,
#   'B01001_026E': 2898.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611009'},
#  {'NAME': 'Census Tract 6110.10; Loudoun County; Virginia',
#   'B01001_001E': 1901.0,
#   'B01001_002E': 657.0,
#   'B01001_026E': 1244.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611010'},
#  {'NAME': 'Census Tract 6110.11; Loudoun County; Virginia',
#   'B01001_001E': 3777.0,
#   'B01001_002E': 1715.0,
#   'B01001_026E': 2062.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611011'},
#  {'NAME': 'Census Tract 6110.12; Loudoun County; Virginia',
#   'B01001_001E': 4578.0,
#   'B01001_002E': 2434.0,
#   'B01001_026E': 2144.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611012'},
#  {'NAME': 'Census Tract 6110.13; Loudoun County; Virginia',
#   'B01001_001E': 5298.0,
#   'B01001_002E': 2702.0,
#   'B01001_026E': 2596.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611013'},
#  {'NAME': 'Census Tract 6110.14; Loudoun County; Virginia',
#   'B01001_001E': 4572.0,
#   'B01001_002E': 2151.0,
#   'B01001_026E': 2421.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611014'},
#  {'NAME': 'Census Tract 6110.15; Loudoun County; Virginia',
#   'B01001_001E': 3155.0,
#   'B01001_002E': 1528.0,
#   'B01001_026E': 1627.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611015'},
#  {'NAME': 'Census Tract 6110.16; Loudoun County; Virginia',
#   'B01001_001E': 4624.0,
#   'B01001_002E': 2401.0,
#   'B01001_026E': 2223.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611016'},
#  {'NAME': 'Census Tract 6110.17; Loudoun County; Virginia',
#   'B01001_001E': 3566.0,
#   'B01001_002E': 1820.0,
#   'B01001_026E': 1746.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611017'},
#  {'NAME': 'Census Tract 6110.18; Loudoun County; Virginia',
#   'B01001_001E': 3794.0,
#   'B01001_002E': 1507.0,
#   'B01001_026E': 2287.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611018'},
#  {'NAME': 'Census Tract 6110.19; Loudoun County; Virginia',
#   'B01001_001E': 5968.0,
#   'B01001_002E': 2944.0,
#   'B01001_026E': 3024.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611019'},
#  {'NAME': 'Census Tract 6110.20; Loudoun County; Virginia',
#   'B01001_001E': 7144.0,
#   'B01001_002E': 3508.0,
#   'B01001_026E': 3636.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611020'},
#  {'NAME': 'Census Tract 6110.22; Loudoun County; Virginia',
#   'B01001_001E': 7090.0,
#   'B01001_002E': 3556.0,
#   'B01001_026E': 3534.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611022'},
#  {'NAME': 'Census Tract 6110.23; Loudoun County; Virginia',
#   'B01001_001E': 6369.0,
#   'B01001_002E': 3281.0,
#   'B01001_026E': 3088.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611023'},
#  {'NAME': 'Census Tract 6110.26; Loudoun County; Virginia',
#   'B01001_001E': 13860.0,
#   'B01001_002E': 7425.0,
#   'B01001_026E': 6435.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611026'},
#  {'NAME': 'Census Tract 6110.27; Loudoun County; Virginia',
#   'B01001_001E': 2523.0,
#   'B01001_002E': 1316.0,
#   'B01001_026E': 1207.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611027'},
#  {'NAME': 'Census Tract 6110.28; Loudoun County; Virginia',
#   'B01001_001E': 6078.0,
#   'B01001_002E': 2971.0,
#   'B01001_026E': 3107.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611028'},
#  {'NAME': 'Census Tract 6110.29; Loudoun County; Virginia',
#   'B01001_001E': 7001.0,
#   'B01001_002E': 3338.0,
#   'B01001_026E': 3663.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611029'},
#  {'NAME': 'Census Tract 6110.30; Loudoun County; Virginia',
#   'B01001_001E': 6701.0,
#   'B01001_002E': 3413.0,
#   'B01001_026E': 3288.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611030'},
#  {'NAME': 'Census Tract 6110.31; Loudoun County; Virginia',
#   'B01001_001E': 2320.0,
#   'B01001_002E': 1096.0,
#   'B01001_026E': 1224.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611031'},
#  {'NAME': 'Census Tract 6110.32; Loudoun County; Virginia',
#   'B01001_001E': 2961.0,
#   'B01001_002E': 1539.0,
#   'B01001_026E': 1422.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611032'},
#  {'NAME': 'Census Tract 6111.01; Loudoun County; Virginia',
#   'B01001_001E': 4922.0,
#   'B01001_002E': 2474.0,
#   'B01001_026E': 2448.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611101'},
#  {'NAME': 'Census Tract 6111.02; Loudoun County; Virginia',
#   'B01001_001E': 5983.0,
#   'B01001_002E': 2894.0,
#   'B01001_026E': 3089.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611102'},
#  {'NAME': 'Census Tract 6112.02; Loudoun County; Virginia',
#   'B01001_001E': 4760.0,
#   'B01001_002E': 2141.0,
#   'B01001_026E': 2619.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611202'},
#  {'NAME': 'Census Tract 6112.04; Loudoun County; Virginia',
#   'B01001_001E': 5268.0,
#   'B01001_002E': 2771.0,
#   'B01001_026E': 2497.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611204'},
#  {'NAME': 'Census Tract 6112.05; Loudoun County; Virginia',
#   'B01001_001E': 6985.0,
#   'B01001_002E': 3318.0,
#   'B01001_026E': 3667.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611205'},
#  {'NAME': 'Census Tract 6112.06; Loudoun County; Virginia',
#   'B01001_001E': 4829.0,
#   'B01001_002E': 2646.0,
#   'B01001_026E': 2183.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611206'},
#  {'NAME': 'Census Tract 6112.07; Loudoun County; Virginia',
#   'B01001_001E': 3834.0,
#   'B01001_002E': 1913.0,
#   'B01001_026E': 1921.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611207'},
#  {'NAME': 'Census Tract 6112.08; Loudoun County; Virginia',
#   'B01001_001E': 4798.0,
#   'B01001_002E': 2576.0,
#   'B01001_026E': 2222.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611208'},
#  {'NAME': 'Census Tract 6112.09; Loudoun County; Virginia',
#   'B01001_001E': 6467.0,
#   'B01001_002E': 3000.0,
#   'B01001_026E': 3467.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611209'},
#  {'NAME': 'Census Tract 6113; Loudoun County; Virginia',
#   'B01001_001E': 6835.0,
#   'B01001_002E': 3108.0,
#   'B01001_026E': 3727.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611300'},
#  {'NAME': 'Census Tract 6114; Loudoun County; Virginia',
#   'B01001_001E': 6362.0,
#   'B01001_002E': 2954.0,
#   'B01001_026E': 3408.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611400'},
#  {'NAME': 'Census Tract 6115.01; Loudoun County; Virginia',
#   'B01001_001E': 4086.0,
#   'B01001_002E': 2183.0,
#   'B01001_026E': 1903.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611501'},
#  {'NAME': 'Census Tract 6115.02; Loudoun County; Virginia',
#   'B01001_001E': 6998.0,
#   'B01001_002E': 3574.0,
#   'B01001_026E': 3424.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611502'},
#  {'NAME': 'Census Tract 6116.01; Loudoun County; Virginia',
#   'B01001_001E': 4035.0,
#   'B01001_002E': 2197.0,
#   'B01001_026E': 1838.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611601'},
#  {'NAME': 'Census Tract 6116.02; Loudoun County; Virginia',
#   'B01001_001E': 4000.0,
#   'B01001_002E': 2284.0,
#   'B01001_026E': 1716.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611602'},
#  {'NAME': 'Census Tract 6117.01; Loudoun County; Virginia',
#   'B01001_001E': 4705.0,
#   'B01001_002E': 2698.0,
#   'B01001_026E': 2007.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611701'},
#  {'NAME': 'Census Tract 6117.02; Loudoun County; Virginia',
#   'B01001_001E': 2533.0,
#   'B01001_002E': 1258.0,
#   'B01001_026E': 1275.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611702'},
#  {'NAME': 'Census Tract 6118.03; Loudoun County; Virginia',
#   'B01001_001E': 7238.0,
#   'B01001_002E': 3793.0,
#   'B01001_026E': 3445.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611803'},
#  {'NAME': 'Census Tract 6118.04; Loudoun County; Virginia',
#   'B01001_001E': 7794.0,
#   'B01001_002E': 3900.0,
#   'B01001_026E': 3894.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611804'},
#  {'NAME': 'Census Tract 6118.05; Loudoun County; Virginia',
#   'B01001_001E': 4601.0,
#   'B01001_002E': 2327.0,
#   'B01001_026E': 2274.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611805'},
#  {'NAME': 'Census Tract 6118.07; Loudoun County; Virginia',
#   'B01001_001E': 7920.0,
#   'B01001_002E': 3913.0,
#   'B01001_026E': 4007.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611807'},
#  {'NAME': 'Census Tract 6118.08; Loudoun County; Virginia',
#   'B01001_001E': 5805.0,
#   'B01001_002E': 3127.0,
#   'B01001_026E': 2678.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611808'},
#  {'NAME': 'Census Tract 6118.09; Loudoun County; Virginia',
#   'B01001_001E': 8292.0,
#   'B01001_002E': 3677.0,
#   'B01001_026E': 4615.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611809'},
#  {'NAME': 'Census Tract 6118.10; Loudoun County; Virginia',
#   'B01001_001E': 7353.0,
#   'B01001_002E': 3627.0,
#   'B01001_026E': 3726.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611810'},
#  {'NAME': 'Census Tract 6118.11; Loudoun County; Virginia',
#   'B01001_001E': 7757.0,
#   'B01001_002E': 3955.0,
#   'B01001_026E': 3802.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611811'},
#  {'NAME': 'Census Tract 6118.12; Loudoun County; Virginia',
#   'B01001_001E': 3262.0,
#   'B01001_002E': 1717.0,
#   'B01001_026E': 1545.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611812'},
#  {'NAME': 'Census Tract 6118.13; Loudoun County; Virginia',
#   'B01001_001E': 11297.0,
#   'B01001_002E': 5752.0,
#   'B01001_026E': 5545.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611813'},
#  {'NAME': 'Census Tract 6119.01; Loudoun County; Virginia',
#   'B01001_001E': 6859.0,
#   'B01001_002E': 3470.0,
#   'B01001_026E': 3389.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611901'},
#  {'NAME': 'Census Tract 6119.02; Loudoun County; Virginia',
#   'B01001_001E': 6202.0,
#   'B01001_002E': 3082.0,
#   'B01001_026E': 3120.0,
#   'state': '51',
#   'county': '107',
#   'tract': '611902'},
#  {'NAME': 'Census Tract 9801; Loudoun County; Virginia',
#   'B01001_001E': 0.0,
#   'B01001_002E': 0.0,
#   'B01001_026E': 0.0,
#   'state': '51',
#   'county': '107',
#   'tract': '980100'},
#  {'NAME': 'Census Tract 9501.01; Louisa County; Virginia',
#   'B01001_001E': 2725.0,
#   'B01001_002E': 1415.0,
#   'B01001_026E': 1310.0,
#   'state': '51',
#   'county': '109',
#   'tract': '950101'},
#  {'NAME': 'Census Tract 9501.02; Louisa County; Virginia',
#   'B01001_001E': 5051.0,
#   'B01001_002E': 2418.0,
#   'B01001_026E': 2633.0,
#   'state': '51',
#   'county': '109',
#   'tract': '950102'},
#  {'NAME': 'Census Tract 9502.01; Louisa County; Virginia',
#   'B01001_001E': 5881.0,
#   'B01001_002E': 2713.0,
#   'B01001_026E': 3168.0,
#   'state': '51',
#   'county': '109',
#   'tract': '950201'},
#  {'NAME': 'Census Tract 9502.02; Louisa County; Virginia',
#   'B01001_001E': 4781.0,
#   'B01001_002E': 2483.0,
#   'B01001_026E': 2298.0,
#   'state': '51',
#   'county': '109',
#   'tract': '950202'},
#  {'NAME': 'Census Tract 9503.01; Louisa County; Virginia',
#   'B01001_001E': 4046.0,
#   'B01001_002E': 2118.0,
#   'B01001_026E': 1928.0,
#   'state': '51',
#   'county': '109',
#   'tract': '950301'},
#  {'NAME': 'Census Tract 9503.02; Louisa County; Virginia',
#   'B01001_001E': 3185.0,
#   'B01001_002E': 1736.0,
#   'B01001_026E': 1449.0,
#   'state': '51',
#   'county': '109',
#   'tract': '950302'},
#  {'NAME': 'Census Tract 9503.03; Louisa County; Virginia',
#   'B01001_001E': 2874.0,
#   'B01001_002E': 1375.0,
#   'B01001_026E': 1499.0,
#   'state': '51',
#   'county': '109',
#   'tract': '950303'},
#  {'NAME': 'Census Tract 9504; Louisa County; Virginia',
#   'B01001_001E': 3162.0,
#   'B01001_002E': 1558.0,
#   'B01001_026E': 1604.0,
#   'state': '51',
#   'county': '109',
#   'tract': '950400'},
#  {'NAME': 'Census Tract 9505; Louisa County; Virginia',
#   'B01001_001E': 6401.0,
#   'B01001_002E': 3262.0,
#   'B01001_026E': 3139.0,
#   'state': '51',
#   'county': '109',
#   'tract': '950500'},
#  {'NAME': 'Census Tract 9301; Lunenburg County; Virginia',
#   'B01001_001E': 5484.0,
#   'B01001_002E': 3225.0,
#   'B01001_026E': 2259.0,
#   'state': '51',
#   'county': '111',
#   'tract': '930100'},
#  {'NAME': 'Census Tract 9302; Lunenburg County; Virginia',
#   'B01001_001E': 4173.0,
#   'B01001_002E': 1944.0,
#   'B01001_026E': 2229.0,
#   'state': '51',
#   'county': '111',
#   'tract': '930200'},
#  {'NAME': 'Census Tract 9303; Lunenburg County; Virginia',
#   'B01001_001E': 2331.0,
#   'B01001_002E': 1116.0,
#   'B01001_026E': 1215.0,
#   'state': '51',
#   'county': '111',
#   'tract': '930300'},
#  {'NAME': 'Census Tract 9301.01; Madison County; Virginia',
#   'B01001_001E': 3495.0,
#   'B01001_002E': 1617.0,
#   'B01001_026E': 1878.0,
#   'state': '51',
#   'county': '113',
#   'tract': '930101'},
#  {'NAME': 'Census Tract 9301.02; Madison County; Virginia',
#   'B01001_001E': 4378.0,
#   'B01001_002E': 2251.0,
#   'B01001_026E': 2127.0,
#   'state': '51',
#   'county': '113',
#   'tract': '930102'},
#  {'NAME': 'Census Tract 9302.01; Madison County; Virginia',
#   'B01001_001E': 3289.0,
#   'B01001_002E': 1555.0,
#   'B01001_026E': 1734.0,
#   'state': '51',
#   'county': '113',
#   'tract': '930201'},
#  {'NAME': 'Census Tract 9302.02; Madison County; Virginia',
#   'B01001_001E': 2666.0,
#   'B01001_002E': 1341.0,
#   'B01001_026E': 1325.0,
#   'state': '51',
#   'county': '113',
#   'tract': '930202'},
#  ...]

# %% [markdown]
# We can **convert it to a pandas dataframe** using the following code.

# %%
va_df = pd.DataFrame(va_census)
va_df
# Out:
#                                                 NAME  B01001_001E  \
# 0     Census Tract 901.01; Accomack County; Virginia       1902.0
# 1     Census Tract 901.02; Accomack County; Virginia       1401.0
# 2     Census Tract 902.01; Accomack County; Virginia       3126.0
# 3     Census Tract 902.02; Accomack County; Virginia       2772.0
# 4        Census Tract 903; Accomack County; Virginia       2225.0
# ...                                              ...          ...
# 2193    Census Tract 1.02; Winchester city; Virginia       3510.0
# 2194    Census Tract 2.01; Winchester city; Virginia       3697.0
# 2195    Census Tract 2.02; Winchester city; Virginia       5598.0
# 2196    Census Tract 3.01; Winchester city; Virginia       5388.0
# 2197    Census Tract 3.02; Winchester city; Virginia       6007.0
#
#       B01001_002E  B01001_026E state county   tract
# 0           996.0        906.0    51    001  090101
# 1           773.0        628.0    51    001  090102
# 2          1507.0       1619.0    51    001  090201
# 3          1193.0       1579.0    51    001  090202
# 4          1159.0       1066.0    51    001  090300
# ...           ...          ...   ...    ...     ...
# 2193       1690.0       1820.0    51    840  000102
# 2194       1864.0       1833.0    51    840  000201
# 2195       2453.0       3145.0    51    840  000202
# 2196       2659.0       2729.0    51    840  000301
# 2197       3286.0       2721.0    51    840  000302
#
# [2198 rows x 7 columns]

# %% [markdown]
# You can **rename the variable names** to make it more self-explanatory.

# %%
va_df = va_df.rename(columns = {"B01001_001E": "Total_Population", "B01001_002E": "Male_Population", "B01001_026E": "Female_Population"})
va_df
# Out:
#                                                 NAME  Total_Population  \
# 0     Census Tract 901.01; Accomack County; Virginia            1902.0
# 1     Census Tract 901.02; Accomack County; Virginia            1401.0
# 2     Census Tract 902.01; Accomack County; Virginia            3126.0
# 3     Census Tract 902.02; Accomack County; Virginia            2772.0
# 4        Census Tract 903; Accomack County; Virginia            2225.0
# ...                                              ...               ...
# 2193    Census Tract 1.02; Winchester city; Virginia            3510.0
# 2194    Census Tract 2.01; Winchester city; Virginia            3697.0
# 2195    Census Tract 2.02; Winchester city; Virginia            5598.0
# 2196    Census Tract 3.01; Winchester city; Virginia            5388.0
# 2197    Census Tract 3.02; Winchester city; Virginia            6007.0
#
#       Male_Population  Female_Population state county   tract
# 0               996.0              906.0    51    001  090101
# 1               773.0              628.0    51    001  090102
# 2              1507.0             1619.0    51    001  090201
# 3              1193.0             1579.0    51    001  090202
# 4              1159.0             1066.0    51    001  090300
# ...               ...                ...   ...    ...     ...
# 2193           1690.0             1820.0    51    840  000102
# 2194           1864.0             1833.0    51    840  000201
# 2195           2453.0             3145.0    51    840  000202
# 2196           2659.0             2729.0    51    840  000301
# 2197           3286.0             2721.0    51    840  000302
#
# [2198 rows x 7 columns]

# %% [markdown]
# # Data merging

# %% [markdown]
# DataFrames can be merged between Pandas and GeoPandas, or between two Pandas or GeoPandas datasets. For example, we can merge the va_tract GeoDataFrame with the va_df DataFrame using the **merge()** function.
#
# This function requires **one or more common key(s) (column names)** in both datasets to perform the merge. Additionally, the how parameter specifies the type of join operation, such as **left, right, or inner join**. You can learn more about merge operations and their options here: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

# %%
va_tract.columns
# Out:
# Index(['STATEFP', 'COUNTYFP', 'TRACTCE', 'GEOID', 'NAME', 'NAMELSAD', 'MTFCC',
#        'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON', 'geometry',
#        'area_km2'],
#       dtype='object')

# %%
va_df.columns
# Out:
# Index(['NAME', 'Total_Population', 'Male_Population', 'Female_Population',
#        'state', 'county', 'tract'],
#       dtype='object')

# %%
# using both county and tract information as key because there might be the same tract number in different counties
VA_merged = pd.merge(va_df, va_tract, left_on=["county", "tract"], right_on = ["COUNTYFP", "TRACTCE"], how = "inner")
VA_merged.head()
# Out:
#                                            NAME_x  Total_Population  \
# 0  Census Tract 901.01; Accomack County; Virginia            1902.0
# 1  Census Tract 901.02; Accomack County; Virginia            1401.0
# 2  Census Tract 902.01; Accomack County; Virginia            3126.0
# 3  Census Tract 902.02; Accomack County; Virginia            2772.0
# 4     Census Tract 903; Accomack County; Virginia            2225.0
#
#    Male_Population  Female_Population state county   tract STATEFP COUNTYFP  \
# 0            996.0              906.0    51    001  090101      51      001
# 1            773.0              628.0    51    001  090102      51      001
# 2           1507.0             1619.0    51    001  090201      51      001
# 3           1193.0             1579.0    51    001  090202      51      001
# 4           1159.0             1066.0    51    001  090300      51      001
#
#   TRACTCE  ...  NAME_y             NAMELSAD  MTFCC FUNCSTAT      ALAND  \
# 0  090101  ...  901.01  Census Tract 901.01  G5020        S   11889599
# 1  090102  ...  901.02  Census Tract 901.02  G5020        S    6652973
# 2  090201  ...  902.01  Census Tract 902.01  G5020        S   67750622
# 3  090202  ...  902.02  Census Tract 902.02  G5020        S  120052501
# 4  090300  ...     903     Census Tract 903  G5020        S  128419397
#
#      AWATER     INTPTLAT      INTPTLON  \
# 0  32123347  +37.9584297  -075.3437520
# 1   5791517  +37.9084048  -075.3953862
# 2  33782725  +37.9744866  -075.4361713
# 3   2763533  +37.9373260  -075.5614807
# 4  61780185  +37.8876208  -075.6629073
#
#                                             geometry      area_km2
# 0  POLYGON ((-75.41176 37.94633, -75.38947 37.963...  4.511969e-09
# 1  POLYGON ((-75.42392 37.89824, -75.42371 37.898...  1.274901e-09
# 2  POLYGON ((-75.5403 37.94601, -75.53994 37.9467...  1.041166e-08
# 3  POLYGON ((-75.64823 37.96677, -75.64742 37.967...  1.258712e-08
# 4  POLYGON ((-75.78396 37.92491, -75.76164 37.941...  1.948255e-08
#
# [5 rows x 21 columns]

# %% [markdown]
# We can select a **subset of columns** necessary for further analysis.

# %%
# columns in the merged data
VA_merged.columns
# Out:
# Index(['NAME_x', 'Total_Population', 'Male_Population', 'Female_Population',
#        'state', 'county', 'tract', 'STATEFP', 'COUNTYFP', 'TRACTCE', 'GEOID',
#        'NAME_y', 'NAMELSAD', 'MTFCC', 'FUNCSTAT', 'ALAND', 'AWATER',
#        'INTPTLAT', 'INTPTLON', 'geometry', 'area_km2'],
#       dtype='object')

# %%
# selecting subset of columns
VA_merged1 = VA_merged[['STATEFP', 'COUNTYFP', 'TRACTCE', 'GEOID', 'Total_Population', 'Male_Population',
       'Female_Population', 'geometry']]
VA_merged1
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID  Total_Population  Male_Population  \
# 0         51      001  090101  51001090101            1902.0            996.0
# 1         51      001  090102  51001090102            1401.0            773.0
# 2         51      001  090201  51001090201            3126.0           1507.0
# 3         51      001  090202  51001090202            2772.0           1193.0
# 4         51      001  090300  51001090300            2225.0           1159.0
# ...      ...      ...     ...          ...               ...              ...
# 2193      51      840  000102  51840000102            3510.0           1690.0
# 2194      51      840  000201  51840000201            3697.0           1864.0
# 2195      51      840  000202  51840000202            5598.0           2453.0
# 2196      51      840  000301  51840000301            5388.0           2659.0
# 2197      51      840  000302  51840000302            6007.0           3286.0
#
#       Female_Population                                           geometry
# 0                 906.0  POLYGON ((-75.41176 37.94633, -75.38947 37.963...
# 1                 628.0  POLYGON ((-75.42392 37.89824, -75.42371 37.898...
# 2                1619.0  POLYGON ((-75.5403 37.94601, -75.53994 37.9467...
# 3                1579.0  POLYGON ((-75.64823 37.96677, -75.64742 37.967...
# 4                1066.0  POLYGON ((-75.78396 37.92491, -75.76164 37.941...
# ...                 ...                                                ...
# 2193             1820.0  POLYGON ((-78.16623 39.1825, -78.16611 39.1828...
# 2194             1833.0  POLYGON ((-78.19726 39.19114, -78.19711 39.191...
# 2195             3145.0  POLYGON ((-78.2005 39.18016, -78.20045 39.1802...
# 2196             2729.0  POLYGON ((-78.18103 39.16647, -78.18063 39.167...
# 2197             2721.0  POLYGON ((-78.19995 39.15314, -78.19963 39.153...
#
# [2198 rows x 8 columns]

# %% [markdown]
# You can apply additional functions, such as generating summary statistics or estimating new columns, in the same way as we did with other DataFrames.

# %%
# calculating percentage of male population
VA_merged1['Male_Population_pct'] = VA_merged1['Male_Population'] *100 / VA_merged1['Total_Population']
# calculating percentage of female population
VA_merged1['Female_Population_pct'] = VA_merged1['Female_Population'] *100 / VA_merged1['Total_Population']
VA_merged1
# Out:
# <ipython-input-21-1585b02c41f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VA_merged1['Male_Population_pct'] = VA_merged1['Male_Population'] *100 / VA_merged1['Total_Population']
# <ipython-input-21-1585b02c41f1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VA_merged1['Female_Population_pct'] = VA_merged1['Female_Population'] *100 / VA_merged1['Total_Population']
#      STATEFP COUNTYFP TRACTCE        GEOID  Total_Population  Male_Population  \
# 0         51      001  090101  51001090101            1902.0            996.0
# 1         51      001  090102  51001090102            1401.0            773.0
# 2         51      001  090201  51001090201            3126.0           1507.0
# 3         51      001  090202  51001090202            2772.0           1193.0
# 4         51      001  090300  51001090300            2225.0           1159.0
# ...      ...      ...     ...          ...               ...              ...
# 2193      51      840  000102  51840000102            3510.0           1690.0
# 2194      51      840  000201  51840000201            3697.0           1864.0
# 2195      51      840  000202  51840000202            5598.0           2453.0
# 2196      51      840  000301  51840000301            5388.0           2659.0
# 2197      51      840  000302  51840000302            6007.0           3286.0
#
#       Female_Population                                           geometry  \
# 0                 906.0  POLYGON ((-75.41176 37.94633, -75.38947 37.963...
# 1                 628.0  POLYGON ((-75.42392 37.89824, -75.42371 37.898...
# 2                1619.0  POLYGON ((-75.5403 37.94601, -75.53994 37.9467...
# 3                1579.0  POLYGON ((-75.64823 37.96677, -75.64742 37.967...
# 4                1066.0  POLYGON ((-75.78396 37.92491, -75.76164 37.941...
# ...                 ...                                                ...
# 2193             1820.0  POLYGON ((-78.16623 39.1825, -78.16611 39.1828...
# 2194             1833.0  POLYGON ((-78.19726 39.19114, -78.19711 39.191...
# 2195             3145.0  POLYGON ((-78.2005 39.18016, -78.20045 39.1802...
# 2196             2729.0  POLYGON ((-78.18103 39.16647, -78.18063 39.167...
# 2197             2721.0  POLYGON ((-78.19995 39.15314, -78.19963 39.153...
#
#       Male_Population_pct  Female_Population_pct
# 0               52.365931              47.634069
# 1               55.174875              44.825125
# 2               48.208573              51.791427
# 3               43.037518              56.962482
# 4               52.089888              47.910112
# ...                   ...                    ...
# 2193            48.148148              51.851852
# 2194            50.419259              49.580741
# 2195            43.819221              56.180779
# 2196            49.350408              50.649592
# 2197            54.702847              45.297153
#
# [2198 rows x 10 columns]

# %%
# estimating average male population percentage by counties
VA_merged1_summary = VA_merged1.groupby('COUNTYFP')['Male_Population_pct'].mean().reset_index()
VA_merged1_summary
# Out:
#     COUNTYFP  Male_Population_pct
# 0        001            53.271459
# 1        003            47.735393
# 2        005            49.903405
# 3        007            49.637388
# 4        009            47.747739
# ..       ...                  ...
# 128      800            48.930928
# 129      810            49.530959
# 130      820            49.929436
# 131      830            48.425211
# 132      840            49.280676
#
# [133 rows x 2 columns]

# %% [markdown]
# # Exporting the shapefile

# %% [markdown]
# Notice that after performing Pandas operations, the merged file has become a Pandas DataFrame object. To export it as a shapefile, we first need to **convert it back to a GeoPandas object**. Make sure to set the correct CRS (Coordinate Reference System).
#
# Additionally, shapefiles consist of multiple files, so we will first **create a folder** to hold them using **!mkdir**. Then, we will export the data using the **.to_file()** function.

# %%
type(VA_merged1)
# Out:
# pandas.core.frame.DataFrame

# %%
# convert to geodataframe
VA_merged1 = gpd.GeoDataFrame(VA_merged1, geometry='geometry', crs="EPSG:3857")
# create folder named VA_tract_population_dat
# !mkdir VA_tract_population_dat
# export shapefile
VA_merged1.to_file(r'VA_tract_population_dat/VA_tract_population_dat.shp')
# Out:
# mkdir: cannot create directory ‘VA_tract_population_dat’: File exists
# <ipython-input-24-e79e0d0553d5>:6: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   VA_merged1.to_file(r'VA_tract_population_dat/VA_tract_population_dat.shp')
# /usr/local/lib/python3.11/dist-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Total_Population' to 'Total_Popu'
#   ogr_write(
# /usr/local/lib/python3.11/dist-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Male_Population' to 'Male_Popul'
#   ogr_write(
# /usr/local/lib/python3.11/dist-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Female_Population' to 'Female_Pop'
#   ogr_write(
# /usr/local/lib/python3.11/dist-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Male_Population_pct' to 'Male_Pop_1'
#   ogr_write(
# /usr/local/lib/python3.11/dist-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Female_Population_pct' to 'Female_P_1'
#   ogr_write(
